# %%
import xml.etree.ElementTree as ET
from fuzzywuzzy import fuzz
import json
import xmltodict
import urllib
import dateutil.parser

# %%
def if_same_person(first, second):
    ser = fuzz.token_set_ratio(first, second)    
    return ser > 75

# %%
def extract_year(time_string):
    return dateutil.parser.parse(time_string).year

# %%
def build_url(first_name, last_name):
    url = "http://export.arxiv.org/api/query?search_query=au:"
    name = last_name + "_" + first_name[0]
    url += name + "&max_results=1000"
    return url

# %%
def get_list(src):
    ret = []
    #try:
    for entry in src['feed'][u'entry']:

        unit = {}

        # get authors
        unit['authors'] = entry['author']

        # get authors' name strings
        if type(entry['author']) is list:
            name_list = [ p['name'] for p in entry['author'] ]
            name_list_string = "; ".join(name_list) + "; "
        else:
            name_list_string = entry['author']['name']
        # get title, w/ name strings attached in the front
        unit['title'] = name_list_string + entry['title']

        # get article id
        unit['id'] = entry['id']

        # get date
        unit['year'] = dateutil.parser.parse(entry['published']).year

        unit['collaborators'] = []
        ret.append(unit)
    #except:
    #    pass
    return ret

# %%
def get_papers(first_name, last_name):
    
    ret = {}
    try:
        url = build_url(first_name, last_name)
        print url
        data = urllib.urlopen(url).read()
        hold = json.loads(json.dumps(xmltodict.parse(data)))
        papers = get_list(hold)
    
    
        for paper in papers:
            pid = paper['id']
            ret[pid] = paper
    except:
        pass
    return ret

# %% [markdown]
# ## Load Profile

# %%
with open("profile.json") as f:
    old_profile_base = json.load(f)

# %%
def make_mapping_from_id_to_person(base):
    mapping = {}
    for p in base['items']:
        mapping[p['member_id']] = p
    return mapping

# %% [markdown]
# #### Build paper list for each professor

# %%
paper_base = {}

# %%
for person in old_profile_base['items']:
    pid = person['member_id']
    
    paper_base[pid] = get_papers(person['name'], person['surname'])
    print person['name'], person['surname'], len(paper_base[pid])

# %%
paper_base

# %% [markdown]
# # Merge databases

# %%
with open("papers.json") as f:
    old_paper_base = json.load(f)
    
with open("profile.json") as f:
    old_profile_base = json.load(f)

# %%
print "Oscar Garcia-Prada"

# %%
def get_unused_min_id(base):
    ids = [p['id'] for p in base['papers']]
    return max(idx)+1

# %%
def make_mapping_from_id_to_person(base):
    mapping = {}
    for p in base['items']:
        mapping[p['member_id']] = p
    return mapping

# %%
def make_all_unique_pairs(mapping):
    ret = []
    keys = mapping.keys()
    for i in range(0, len(keys)-1):
        for j in range(i+1, len(keys)):
            ret.append((keys[i],keys[j]))
    return ret

# %%
temp_paper_base = {}
temp_paper_collaborator = {}

# %%
# find papers

id2person = make_mapping_from_id_to_person(old_profile_base)
pairs = make_all_unique_pairs(id2person)

for person in id2person.values():
    if type(person['gear_collaborators']) is not list:
        person['gear_collaborators'] = []
        
for pair in pairs:
    
    if(len(temp_paper_base)%10 == 0):
        print len(temp_paper_base)
        
    p0 = id2person[pair[0]]
    p1 = id2person[pair[1]]
    papers = get_papers(p0['surname'], p0['name'], p1['surname'], p1['name'])
    
    for p in papers:
        pid = p['id']
        temp_paper_base[pid] = p
        if pid in temp_paper_collaborator:
            temp_paper_collaborator[pid].extend([pair[0], pair[1]])
            temp_paper_collaborator[pid] = list(set(temp_paper_collaborator[pid]))
        else:
            temp_paper_collaborator[pid] = [pair[0], pair[1]]

# %%
# main

id2person = make_mapping_from_id_to_person(old_profile_base)
pairs = make_all_unique_pairs(id2person)

for person in id2person.values():
    if type(person['gear_collaborators']) is not list:
        person['gear_collaborators'] = []
        
for pair in pairs:
    p0 = id2person[pair[0]]
    p1 = id2person[pair[1]]
    papers = get_papers(p0['surname'], p0['name'], p1['surname'], p1['name'])
    if len(papers) > 0:
        
        p0['gear_collaborators'].append(pair[1])
        p0['gear_collaborators'] = list(set(p0['gear_collaborators']))
        p1['gear_collaborators'].append(pair[0])
        p1['gear_collaborators'] = list(set(p1['gear_collaborators']))

# %%
data = urllib.urlopen("http://export.arxiv.org/api/query?search_query=au:Bradlow_S&max_results=1000").read()

# %%
data
# Out:
# '<?xml version="1.0" encoding="UTF-8"?>\n<feed xmlns="http://www.w3.org/2005/Atom">\n  <link href="http://arxiv.org/api/query?search_query%3Dau%3ABradlow_S%26id_list%3D%26start%3D0%26max_results%3D1000" rel="self" type="application/atom+xml"/>\n  <title type="html">ArXiv Query: search_query=au:Bradlow_S&amp;id_list=&amp;start=0&amp;max_results=1000</title>\n  <id>http://arxiv.org/api/pG4cmntU0oTaAlHarLLoqS4Jr+s</id>\n  <updated>2016-03-29T00:00:00-04:00</updated>\n  <opensearch:totalResults xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">24</opensearch:totalResults>\n  <opensearch:startIndex xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">0</opensearch:startIndex>\n  <opensearch:itemsPerPage xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">1000</opensearch:itemsPerPage>\n  <entry>\n    <id>http://arxiv.org/abs/alg-geom/9506008v1</id>\n    <updated>1995-06-05T23:50:03Z</updated>\n    <published>1995-06-05T23:50:03Z</published>\n    <title>Hermitian-Einstein Inequalities and Harder-Narasimhan Filtration</title>\n    <summary>  Unstable holomorphic bundles can be described algebraically by\nHarder-Narasimhan filtrations. In this note we show how such filtrations\ncorrespond to the existence of special metrics defined by Hermitian-Einstein\ninequalities.\n</summary>\n    <author>\n      <name>Steven B. Bradlow</name>\n    </author>\n    <arxiv:comment xmlns:arxiv="http://arxiv.org/schemas/atom">AMSTeX v2.1, to appear in Int.J.Math</arxiv:comment>\n    <link href="http://arxiv.org/abs/alg-geom/9506008v1" rel="alternate" type="text/html"/>\n    <link title="pdf" href="http://arxiv.org/pdf/alg-geom/9506008v1" rel="related" type="application/pdf"/>\n    <arxiv:primary_category xmlns:arxiv="http://arxiv.org/schemas/atom" term="alg-geom" scheme="http://arxiv.org/schemas/atom"/>\n    <category term="alg-geom" scheme="http://arxiv.org/schemas/atom"/>\n    <category term="math.AG" scheme="http://arxiv.org/schemas/atom"/>\n  </entry>\n  <entry>\n    <id>http://arxiv.org/abs/alg-geom/9304001v2</id>\n    <updated>1993-04-08T14:54:24Z</updated>\n    <published>1993-04-06T18:22:39Z</published>\n    <title>Birational Equivalences of Vortex Moduli</title>\n    <summary>  We construct a finite dimensional Kaehler manifold with a holomorphic,\nsymplectic circle action whose symplectic reduced spaces may be identified with\nthe tau-vortex moduli spaces (or tau-stable pairs). The Morse theory of the\ncircle action induces natural birational maps between the reduced spaces for\ndifferent values of tau which in the case of rank two bundles can be\ncanonically resolved in a sequence of blow-ups and blow-downs.\n</summary>\n    <author>\n      <name>S. Bradlow</name>\n    </author>\n    <author>\n      <name>G. Daskalopoulos</name>\n    </author>\n    <author>\n      <name>R. Wentworth</name>\n    </author>\n    <arxiv:comment xmlns:arxiv="http://arxiv.org/schemas/atom">40 pages in Plain TeX (same as the original, but with TeXnical errors\n  removed)</arxiv:comment>\n    <link href="http://arxiv.org/abs/alg-geom/9304001v2" rel="alternate" type="text/html"/>\n    <link title="pdf" href="http://arxiv.org/pdf/alg-geom/9304001v2" rel="related" type="application/pdf"/>\n    <arxiv:primary_category xmlns:arxiv="http://arxiv.org/schemas/atom" term="alg-geom" scheme="http://arxiv.org/schemas/atom"/>\n    <category term="alg-geom" scheme="http://arxiv.org/schemas/atom"/>\n    <category term="math.AG" scheme="http://arxiv.org/schemas/atom"/>\n  </entry>\n  <entry>\n    <id>http://arxiv.org/abs/alg-geom/9602010v2</id>\n    <updated>1996-03-08T18:22:37Z</updated>\n    <published>1996-02-09T20:50:43Z</published>\n    <title>Non-abelian monopoles and vortices</title>\n    <summary>  The Seiberg-Witten equations are defined on certain complex line bundles over\nsmooth oriented four manifolds. When the base manifold is a complex Kahler\nsurface, the Seiberg-Witten equations are essentially the Abelian vortex\nequations. Using known non-abelian gen ...

# %%
hold = json.loads(json.dumps(xmltodict.parse(data)))

# %%
hold
# Out:
# {u'feed': {u'@xmlns': u'http://www.w3.org/2005/Atom',
#   u'entry': [{u'arxiv:comment': {u'#text': u'AMSTeX v2.1, to appear in Int.J.Math',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'alg-geom',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': {u'name': u'Steven B. Bradlow'},
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'alg-geom'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.AG'}],
#     u'id': u'http://arxiv.org/abs/alg-geom/9506008v1',
#     u'link': [{u'@href': u'http://arxiv.org/abs/alg-geom/9506008v1',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/alg-geom/9506008v1',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'1995-06-05T23:50:03Z',
#     u'summary': u'Unstable holomorphic bundles can be described algebraically by\nHarder-Narasimhan filtrations. In this note we show how such filtrations\ncorrespond to the existence of special metrics defined by Hermitian-Einstein\ninequalities.',
#     u'title': u'Hermitian-Einstein Inequalities and Harder-Narasimhan Filtration',
#     u'updated': u'1995-06-05T23:50:03Z'},
#    {u'arxiv:comment': {u'#text': u'40 pages in Plain TeX (same as the original, but with TeXnical errors\n  removed)',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'alg-geom',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'name': u'S. Bradlow'},
#      {u'name': u'G. Daskalopoulos'},
#      {u'name': u'R. Wentworth'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'alg-geom'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.AG'}],
#     u'id': u'http://arxiv.org/abs/alg-geom/9304001v2',
#     u'link': [{u'@href': u'http://arxiv.org/abs/alg-geom/9304001v2',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/alg-geom/9304001v2',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'1993-04-06T18:22:39Z',
#     u'summary': u'We construct a finite dimensional Kaehler manifold with a holomorphic,\nsymplectic circle action whose symplectic reduced spaces may be identified with\nthe tau-vortex moduli spaces (or tau-stable pairs). The Morse theory of the\ncircle action induces natural birational maps between the reduced spaces for\ndifferent values of tau which in the case of rank two bundles can be\ncanonically resolved in a sequence of blow-ups and blow-downs.',
#     u'title': u'Birational Equivalences of Vortex Moduli',
#     u'updated': u'1993-04-08T14:54:24Z'},
#    {u'arxiv:comment': {u'#text': u'Revised version, in which some minor clarrifications and a number of\n  unjustly ommitted references have been added. (Apologies to any inadvertantly\n  offended parties.) To appear in the Proceedings of the 1995 Aarhus Conference\n  in Geometry and Physics. 25 pages. AMSLaTeX v 2.09',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'alg-geom',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'name': u'Steven Bradlow'},
#      {u'name': u'Oscar Garcia-Prada'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'alg-geom'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'dg-ga'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'}],
#     u'id': u'http://arxiv.org/abs/alg-geom/9602010v2',
#     u'link': [{u'@href': u'http://arxiv.org/abs/alg-geom/9602010v2',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/alg-geom/9602010v2',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'1996-02-09T20:50:43Z',
#     u'summary': u'The Seiberg-Witten equations are defined on certain complex line bundles over\nsmooth oriented four manifolds. When the base manifold is a complex Kahler\nsurface, the Seiberg-Witten equations are essentially the Abelian vortex\nequations. Using known non-abelian generalizations of the vortex equations as a\nguide, we explore some non-abelian versions of the Seiberg-Witten equations. We\nalso make some comments about the differences between the vortex equations that\nhave previously appeared in the literature and those that emerge as Kahler\nversions of Seiberg-witten type equations.',
#     u'title': u'Non-abelian monopoles and vortices',
#     u'updated': u'1996-03-08T18:22:37Z'},
#    {u'arxiv:comment': {u'#text': u'38 pages, J. Fixed Point Theory Appl. 11 (2012), no. 1',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.DG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'name': u'Steven Bradlow'}, {u'name': u'Graeme Wilkin'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'58E, 53C'}],
#     u'id': u'http://arxiv.org/abs/1308.1460v1',
#     u'link': [{u'@href': u'http://arxiv.org/abs/1308.1460v1',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/1308.1460v1',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2013-08-07T01:09:12Z',
#     u'summary': u'In this paper we give an overview of different Morse-theoretic methods used\nto study the topology of moduli spaces of Higgs bundles.',
#     u'title': u'Morse Theory, Higgs fields and Yang-Mills-Higgs functionals',
#     u'updated': u'2013-08-07T01:09:12Z'},
#    {u'arxiv:comment': {u'#text': u'41 pages, LaTeX',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'alg-geom',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'name': u'Steven B. Bradlow'},
#      {u'name': u'Oscar Garcia-Prada'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'alg-geom'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.AG'}],
#     u'id': u'http://arxiv.org/abs/alg-geom/9401008v2',
#     u'link': [{u'@href': u'http://arxiv.org/abs/alg-geom/9401008v2',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/alg-geom/9401008v2',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'1994-01-25T21:59:48Z',
#     u'summary': u'This is a resubmission of preprint 9401008 , which has some TeXnical errors\nintroduced by the "reform" procedure (designed to avoid precisely these\nproblems!). The original can be formatted by editing out the messages "%%\nfollowing line cannot be broken..." at line 1674. This problem has been\ncorrected in the current version. The content of the paper has not been changed\nin any way. My aplogies for any inconvenience caused. SB',
#     u'title': u'Stable triples, equivariant bundles and dimensional reduction',
#     u'updated': u'1994-01-26T15:49:51Z'},
#    {u'arxiv:comment': {u'#text': u'contact authors at bradlow@uiuc.edu or OGPRADA@ccuam3.sdi.uam.es,\n  AMSTeX v2.1',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'alg-geom',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'name': u'Steven B. Bradlow'},
#      {u'name': u'Oscar Garcia-Prada'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'alg-geom'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.AG'}],
#     u'id': u'http://arxiv.org/abs/alg-geom/9506014v1',
#     u'link': [{u'@href': u'http://arxiv.org/abs/alg-geom/9506014v1',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/alg-geom/9506014v1',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'1995-06-20T18:34:32Z',
#     u'summary': u'We introduce equations for special metrics, and notions of stability for some\nnew types of augmented holomorphic bundles. These new examples include\nholomorphic extensions, and in this case we prove a Hitchin-Kobayashi\ncorrespondence between a certain deformation of the Hermitian-Einstein\nequations and our definition of stability for an extension.',
#     u'title': u'Higher cohomology triples and holomorphic extensions',
#     u'updated': u'1995-06-20T18:34:32Z'},
#    {u'arxiv:comment': {u'#text': u'15 pages, AMSTeX v 2.1',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'alg-geom',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'name': u'Steven B. Bradlow'},
#      {u'name': u'Oscar Garcia-Prada'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'alg-geom'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.AG'}],
#     u'id': u'http://arxiv.org/abs/alg-geom/9602003v1',
#     u'link': [{u'@href': u'http://arxiv.org/abs/alg-geom/9602003v1',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/alg-geom/9602003v1',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'1996-02-02T19:58:23Z',
#     u'summary': u"A `coherent system' $(\\Cal E,V)$, consists of a holomorphic bundle plus a\nlinear subspace of its space of holomorphic sections. Based on the usual notion\nin Geometric Invariant Theory, a notion of slope stability has been defined for\nsuch objects (by Le Potier, and also by Rhagavendra and Vishwanath). In this\npaper we show that stability in this sense is equivalent to the existence of\nsolutions to a certain set of gauge theoretic equations. One of the equations\nis essentially the vortex equation (i.e. the Hermitian-Einstein equation with\nan additional zeroth order term), and the other is an orthonormality condition\non a frame for the subspace $V\\subset H^0(\\Cal E)$.",
#     u'title': u'A Hitchin-Kobayashi Correspondence for Coherent Systems on Riemann\n  Surfaces',
#     u'updated': u'1996-02-02T19:58:23Z'},
#    {u'arxiv:comment': {u'#text': u'23 pages, AMSTeX, to be published in the Proceedings of the First\n  USA/Brazil Workshop on Geometry, Topology and Physics, held in Campinas,\n  Brazil, June 1996',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'alg-geom',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'name': u'Steven Bradlow'},
#      {u'name': u'James Glazebrook'},
#      {u'name': u'Franz Kamber'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'alg-geom'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'dg-ga'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'}],
#     u'id': u'http://arxiv.org/abs/alg-geom/9703019v1',
#     u'link': [{u'@href': u'http://arxiv.org/abs/alg-geom/9703019v1',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/alg-geom/9703019v1',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'1997-03-14T14:33:44Z',
#     u'summary': u'In order to use the technique of dimensional reduction, it is usually\nnecessary for there to be a symmetry coming from a group action. In this paper\nwe consider a situation in which there is no such symmetry, but in which a type\nof dimensional reduction is nevertheless possible. We obtain a relation between\nthe Coupled Vortex equations on a closed Kahler manifold, $X$, and the\nHermitian-Einstein equations on certain $P^1$-bundles over $X$. Our results\nthus generalize the dimensional reduction results of Garcia-Prada, which apply\nwhen the Hermitian-Einstein equations are on $X\\times P^1$.',
#     u'title': u'A New look at the vortex equations and dimensional reduction',
#     u'updated': u'1997-03-14T14:33:44Z'},
#    {u'arxiv:comment': {u'#text': u'34 pages, 2 tables',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'name': u'Steven B. Bradlow'}, {u'name': u'Tomas L. Gomez'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'}],
#     u'id': u'http://arxiv.org/abs/math/0009044v1',
#     u'link': [{u'@href': u'http://arxiv.org/abs/math/0009044v1',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0009044v1',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2000-09-05T17:34:34Z',
#     u'summary': u"We prove a Hitchin-Kobayashi correspondence for extensions of Higgs bundles.\nThe results generalize known results for extensions of holomorphic bundles.\nUsing Simpson's methods, we construct moduli spaces of stable objects. In an\nappendix we construct Bott-Chern forms for Higgs bundles",
#     u'title': u'Extensions of Higgs Bundles',
#     u'updated': u'2000-09-05T17:34:34Z'},
#    {u'arxiv:comment': {u'#text': u'44 pages, Latex2e',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'name': u'Steven Bradlow'},
#      {u'name': u'Oscar Garcia-Prada'},
#      {u'name': u'Vicente Mu\xf1oz'},
#      {u'name': u'Peter Newstead'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14D20; 14H51; 14H60'}],
#     u'id': u'http://arxiv.org/abs/math/0205317v1',
#     u'link': [{u'@href': u'http://arxiv.org/abs/math/0205317v1',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0205317v1',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2002-05-30T11:59:38Z',
#     u'summary': u'Let $C$ be a curve of genus $g\\geq 2$. A coherent system on $C$ consists of a\npair $(E,V)$ where $E$ is an algebraic vector bundle of rank $n$ and degree $d$\nand $V$ is a subspace of dimension $k$ of sections of $E$. The stability of the\ncoherent systems depend on a parameter $\\tau$. We study the variation of the\nmoduli space of coherent systems when we move the parameter. As an application,\nwe analyse the cases $k=1,2,3$ and $n=2$ explicitly. For small values of\n$\\tau$, the moduli space of coherent systems is related to the Brill-Noether\nloci, the subspaces of the moduli space of stable bundles consisting of those\nbundles with a prescribed number of sections. The study of coherent systems is\napplied to find the dimension, irreducibility, and in some cases, the Picard\ngroup, of the Brill-Noether loci with $k\\leq 3$.',
#     u'title': u'Coherent systems and Brill-Noether theory',
#     u'updated': u'2002-05-30T11:59:38Z'},
#    {u'arxiv:comment': {u'#text': u'38 pages; v3. Appendix and new references added; v4. minor\n  corrections, two added references; v5. final version, one typo corrected and\n  one reference deleted',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'name': u'S. Bradlow'},
#      {u'name': u'O. Garcia-Prada'},
#      {u'name': u'V. Mercat'},
#      {u'name': u'V. Mu\xf1oz'},
#      {u'name': u'P. Newstead'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14D20; 14H51; 14H60'}],
#     u'id': u'http://arxiv.org/abs/math/0407523v5',
#     u'link': [{u'@href': u'http://arxiv.org/abs/math/0407523v5',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0407523v5',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2004-07-30T07:24:43Z',
#     u'summary': u"Let $C$ be an algebraic curve of genus $g$. A coherent system on $C$ consists\nof a pair $(E,V)$, where $E$ is an algebraic vector bundle over $C$ of rank $n$\nand degree $d$ and $V$ is a subspace of dimension $k$ of the space of sections\nof $E$. The stability of the coherent system depends on a parameter $\\alpha$.\nWe study the geometry of the moduli space of coherent systems for different\nvalues of $\\alpha$ when $k\\leq n$ and the variation of the moduli spaces when\nwe vary $\\alpha$. As a consequence, for sufficiently large $\\alpha$, we compute\nthe Picard groups and the first and second homotopy groups of the moduli spaces\nof coherent systems in almost all cases, describe the moduli space for the case\n$k=n-1$ explicitly, and give the Poincar\\'e polynomials for the case $k=n-2$.",
#     u'title': u'On the geometry of moduli spaces of coherent systems on algebraic curves',
#     u'updated': u'2006-08-02T06:55:44Z'},
#    {u'arxiv:comment': {u'#text': u'Inadvertent omission in Acknowledgements corrected',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'name': u'Steven B. Bradlow'},
#      {u'name': u'Laura P. Schaposnik'}],
#     u'category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG'},
#     u'id': u'http://arxiv.org/abs/1508.02650v2',
#     u'link': [{u'@href': u'http://arxiv.org/abs/1508.02650v2',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/1508.02650v2',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2015-08-11T16:31:25Z',
#     u'summary': u"We explore relations between Higgs bundles that result from isogenies between\nlow-dimensional Lie groups, with special attention to the spectral data for the\nHiggs bundles. We focus on isogenies onto $SO(4,C)$ and $SO(6,C)$ and their\nsplit real forms. Using fiber products of spectral curves, we obtain directly\nthe desingularizations of the (necessarily singular) spectral curves associated\nto orthogonal Higgs bundles. In the case of $SO(6,C)$ our construction can be\ninterpreted as a new description of Recillas' trigonal construction.",
#     u'title': u'Higgs bundles and exceptional isogenies',
#     u'updated': u'2015-08-13T12:52:57Z'},
#    {u'arxiv:comment': {u'#text': u'106 pages',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'name': u'Steven B. Bradlow'},
#      {u'name': u'Oscar Garcia-Prada'},
#      {u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14H30, 14H60, 32L05'}],
#     u'id': u'http://arxiv.org/abs/math/0206012v1',
#     u'link': [{u'@href': u'http://arxiv.org/abs/math/0206012v1',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0206012v1',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2002-06-03T13:23:50Z',
#     u'summary': u"Using the $L^2$ norm of the Higgs field as a Morse function, we study the\nmoduli spaces of $U(p,q)$-Higgs bundles over a Riemann surface. We require that\nthe genus of the surface be at least two, but place no constraints on $(p,q)$.\nA key step is the identification of the function's local minima as moduli\nspaces of holomorphic triples. We prove that these moduli spaces of triples are\nirreducible and non-empty.\n  Because of the relation between flat bundles and fundamental group\nrepresentations, we can interpret our conclusions as results about the number\nof connected components in the moduli space of semisimple\n$PU(p,q)$-representations. The topological invariants of the flat bundles\nbundle are used to label components. These invariants are bounded by a\nMilnor-Wood type inequality. For each allowed value of the invariants\nsatisfying a certain coprimality condition, we prove that the corresponding\ncomponent is non-empty and connected. If the coprimality condition does not\nhold, our results apply to the irreducible representations.",
#     u'title': u'Surface group representations, Higgs bundles, and holomorphic triples',
#     u'updated': u'2002-06-03T13:23:50Z'},
#    {u'arxiv:comment': {u'#text': u'27 pages; minor presentational changes and typographical corrections',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'name': u'S. B. Bradlow'},
#      {u'name': u'O. Garcia-Prada'},
#      {u'name': u'V. Mercat'},
#      {u'name': u'V. Munoz'},
#      {u'name': u'P. E. Newstead'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14H60, 14D20, 14H51'}],
#     u'id': u'http://arxiv.org/abs/0707.0983v2',
#     u'link': [{u'@href': u'http://arxiv.org/abs/0707.0983v2',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/0707.0983v2',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2007-07-06T14:41:46Z',
#     u'summary': u'Let $C$ be an algebraic curve of genus $g\\ge2$. A coherent system on $C$\nconsists of a pair $(E,V)$, where $E$ is an algebraic vector bundle over $C$ of\nrank $n$ and degree $d$ and $V$ is a subspace of dimension $k$ of the space of\nsections of $E$. The stability of the coherent system depends on a parameter\n$\\alpha$. We study the geometry of the moduli space of coherent systems for\n$0<d\\le2n$. We show that these spaces are irreducible whenever they are\nnon-empty and obtain necessary and sufficient conditions for non-emptiness.',
#     u'title': u'Moduli spaces of coherent systems of small slope on algebraic curves',
#     u'updated': u'2007-12-10T13:55:56Z'},
#    {u'arxiv:comment': {u'#text': u'38 pages',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.DG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'name': u'Steven B. Bradlow'},
#      {u'name': u'Oscar Garcia-Prada'},
#      {u'name': u'Ignasi Mundet i Rierra'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.AG'}],
#     u'id': u'http://arxiv.org/abs/math/0206003v1',
#     u'link': [{u'@href': u'http://arxiv.org/abs/math/0206003v1',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0206003v1',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2002-06-03T16:58:00Z',
#     u'summary': u'A principal pair consists of a holomorphic principal $G$-bundle together with\na holomorphic section of an associated Kaehler fibration. Such objects support\nnatural gauge theoretic equations coming from a moment map condition, and also\nadmit a notion of stability based on Geometric Invariant Theory. The\nHitchin--Kobayashi correspondence for principal pairs identifies stability as\nthe condition for the existence of solutions to the equations. In this paper we\ngeneralize these features in a way which allows the full gauge group of the\nprincipal bundle to be replaced by certain proper subgroups. Such a\ngeneralization is needed in order to use principal pairs as a general framework\nfor describing augmented holomorphic bundles. We illustrate our results with\napplications to well known examples.',
#     u'title': u'Relative Hitchin--Kobayashi correspondences for principal pairs',
#     u'updated': u'2002-06-03T16:58:00Z'},
#    {u'arxiv:comment': {u'#text': u'44 pages. v2: minor clarifications and corrections, to appear in\n  Math. Annalen',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:doi': {u'#text': u'10.1007/s00208-003-0484-z',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:journal_ref': {u'#text': u'Math. Ann. 328 (2004), 299-351.',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Steven B. Bradlow'},
#      {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Oscar Garcia-Prada'},
#      {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14D20 (Primary) 14H60, 32G13 (Secondary)'}],
#     u'id': u'http://arxiv.org/abs/math/0211428v2',
#     u'link': [{u'@href': u'http://dx.doi.org/10.1007/s00208-003-0484-z',
#       u'@rel': u'related',
#       u'@title': u'doi'},
#      {u'@href': u'http://arxiv.org/abs/math/0211428v2',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0211428v2',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2002-11-27T15:06:44Z',
#     u'summary': u'A holomorphic triple over a compact Riemann surface consists of two\nholomorphic vector bundles and a holomorphic map between them. After fixing the\ntopological types of the bundles and a real parameter, there exist moduli\nspaces of stable holomorphic triples. In this paper we study non-emptiness,\nirreducibility, smoothness, and birational descriptions of these moduli spaces\nfor a certain range of the parameter. Our results have important applications\nto the study of the moduli space of representations of the fundamental group of\nthe surface into unitary Lie groups of indefinite signature, which we explore\nin a companion paper "Surface group representations in PU(p,q) and Higgs\nbundles". Another application, that we study in this paper, is to the existence\nof stable bundles on the product of the surface by the complex projective line.\n This paper, and its companion mentioned above, form a substantially revised\nversion of math.AG/0206012.',
#     u'title': u'Moduli spaces of holomorphic triples over compact Riemann surfaces',
#     u'updated': u'2003-10-02T09:13:55Z'},
#    {u'arxiv:comment': {u'#text': u'44 pages, 2 figures. Minor clarifications and corrections. Final\n  version, to appear in J. Diff. Geom',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:journal_ref': {u'#text': u'J. Diff. Geom. 64 (2003), 111-170.',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Steven B. Bradlow'},
#      {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Oscar Garcia-Prada'},
#      {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14D20 (Primary) 14H60, 32G13 (Secondary)'}],
#     u'id': u'http://arxiv.org/abs/math/0211431v3',
#     u'link': [{u'@href': u'http://arxiv.org/abs/math/0211431v3',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0211431v3',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2002-11-27T15:31:01Z',
#     u'summary': u'Using the L^2 norm of the Higgs field as a Morse function, we study the\nmoduli spaces of U(p,q)-Higgs bundles over a Riemann surface. We require that\nthe genus of the surface be at least two, but place no constraints on (p,q). A\nkey step is the identification of the function\'s local minima as moduli spaces\nof holomorphic triples. In a companion paper "Moduli spaces of holomorphic\ntriples over compact Riemann surfaces" (math.AG/0211428) we prove that these\nmoduli spaces of triples are non-empty and irreducible.\n Because of the relation between flat bundles and fundamental group\nrepresentations, we can interpret our conclusions as results about the number\nof connected components in the moduli space of semisimple\nPU(p,q)-representations. The topological invariants of the flat bundles are\nused to label subspaces. These invariants are bounded by a Milnor-Wood type\ninequality. For each allowed value of the invariants satisfying a certain\ncoprimality condition, we prove that the corresponding subspace is non-empty\nand connected. If the coprimality condition does not hold, our results apply to\nthe closure of the moduli space of irreducible representations.\n This paper, and its companion mentioned above, form a substantially revised\nversion of math.AG/0206012.',
#     u'title': u'Surface group representations in PU(p,q) and Higgs bundles',
#     u'updated': u'2003-07-11T08:54:37Z'},
#    {u'arxiv:comment': {u'#text': u'12 pages. v2: corrected statement of Theorem 5.2 (1), other minor\n  corrections. To appear in the Proceedings of the Fall Workshop on Geometry\n  and Physics, Coimbra 2003',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:journal_ref': {u'#text': u'Proceedings of the XII Fall Workshop on Geometry and Physics,\n  Coimbra 2003, Publicaciones de la RSME 7 (2004), 83-94',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Steven B. Bradlow'},
#      {u'arxiv:affiliation': {u'#text': u'IMAFF, CSIC, Madrid',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Oscar Garcia-Prada'},
#      {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14D20, 14F45, 14H60'}],
#     u'id': u'http://arxiv.org/abs/math/0401064v2',
#     u'link': [{u'@href': u'http://arxiv.org/abs/math/0401064v2',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0401064v2',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2004-01-07T17:29:15Z',
#     u'summary': u'We determine the number of connected components of the moduli space for\nrepresentations of a surface group in the general linear group.',
#     u'title': u'Representations of surface groups in the general linear group',
#     u'updated': u'2004-01-19T11:28:48Z'},
#    {u'arxiv:comment': {u'#text': u'13 pages',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:journal_ref': {u'#text': u'Proc. in Global Analysis, Diff. Geometry and Lie Algebras, Balkan\n  Geometry Press, Bucharest 2001, pp. 43-62',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.DG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'name': u'Steven B. Bradlow'},
#      {u'name': u'James F. Glazebrook'},
#      {u'name': u'Franz W. Kamber'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'58D27, 22B40, 32L10, 58G10, 53C07'}],
#     u'id': u'http://arxiv.org/abs/math/0405205v1',
#     u'link': [{u'@href': u'http://arxiv.org/abs/math/0405205v1',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0405205v1',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2004-05-12T06:05:22Z',
#     u'summary': u'Given a Kaehlerian holomorphic fiber bundle whose fiber is a compact\nhomogeneous Kaehler manifold, we describe the perturbed Hermitian-Einstein\nequations relative to certain holomorphic vector bundles. With respect to\nspecial metrics on the holomorphic bundles, there is a dimensional reduction\nprocedure which reduces these equations to a system of equations on the base,\nknown as the twisted coupled vortex equations.',
#     u'title': u'Dimensional reduction of the perturbed Hermitian-Einstein equation',
#     u'updated': u'2004-05-12T06:05:22Z'},
#    {u'arxiv:comment': {u'#text': u'21 pages; v2: improved results for moduli of representations in\n  GL(n,C), provided proof of Proposition 4.13 (4.12 of v1) correcting argument\n  given in earlier paper, other minor corrections; v3: corrected Remark 4.6,\n  other minor corrections; v4: corrected statements of Proposition 4.17 and\n  Theorems 4.19 and 4.22 (former Theorems 4.18 and 4.20); to appear in Topology',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:doi': {u'#text': u'10.1016/j.top.2007.06.001',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:journal_ref': {u'#text': u'Topology 47 (2008), 203-224',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Steven B. Bradlow'},
#      {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Oscar Garcia-Prada'},
#      {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14H60, 57R57, 58D29'}],
#     u'id': u'http://arxiv.org/abs/math/0506444v4',
#     u'link': [{u'@href': u'http://dx.doi.org/10.1016/j.top.2007.06.001',
#       u'@rel': u'related',
#       u'@title': u'doi'},
#      {u'@href': u'http://arxiv.org/abs/math/0506444v4',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0506444v4',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2005-06-22T10:49:12Z',
#     u'summary': u'We calculate certain homotopy groups of the moduli spaces for representations\nof a compact oriented surface in the Lie groups GL(n,C) and U(p,q). Our\napproach relies on the interpretation of these representations in terms of\nHiggs bundles and uses Bott--Morse theory on the corresponding moduli spaces.',
#     u'title': u'Homotopy groups of moduli spaces of representations',
#     u'updated': u'2007-06-14T09:57:44Z'},
#    {u'arxiv:comment': {u'#text': u'v2: added due credits to the work of Burger, Iozzi and Wienhard. v3:\n  corrected count of connected components for G=SU(p,q) (p \\neq q); added due\n  credits to the work of Xia and Markman-Xia; minor corrections and\n  clarifications. 31 pages',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:doi': {u'#text': u'10.1007/s10711-007-9127-y',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:journal_ref': {u'#text': u'Geometriae Dedicata 122 (2006), 185-213',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Steven B. Bradlow'},
#      {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Oscar Garcia-Prada'},
#      {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14H60 (Primary) 57R57, 58D29 (Secondary)'}],
#     u'id': u'http://arxiv.org/abs/math/0511415v3',
#     u'link': [{u'@href': u'http://dx.doi.org/10.1007/s10711-007-9127-y',
#       u'@rel': u'related',
#       u'@title': u'doi'},
#      {u'@href': u'http://arxiv.org/abs/math/0511415v3',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0511415v3',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2005-11-16T16:07:34Z',
#     u'summary': u'Higgs bundles and non-abelian Hodge theory provide holomorphic methods with\nwhich to study the moduli spaces of surface group representations in a\nreductive Lie group G. In this paper we survey the case in which G is the\nisometry group of a classical Hermitian symmetric space of non-compact type.\nUsing Morse theory on the moduli spaces of Higgs bundles, we compute the number\nof connected components of the moduli space of representations with maximal\nToledo invariant.',
#     u'title': u'Maximal surface group representations in isometry groups of classical\n  Hermitian symmetric spaces',
#     u'updated': u'2006-11-27T11:57:56Z'},
#    {u'arxiv:comment': {u'#text': u'49 pages; v2: various improvements and minor corrections; v3:\n  improved exposition',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:doi': {u'#text': u'10.1093/qmath/har010',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:journal_ref': {u'#text': u'Q. J. Math. 63 (2012), 795-843',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Steven B. Bradlow'},
#      {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Oscar Garcia-Prada'},
#      {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14H60 (Primary) 57M99, 22E99 (Secondary)'}],
#     u'id': u'http://arxiv.org/abs/0903.5496v3',
#     u'link': [{u'@href': u'http://dx.doi.org/10.1093/qmath/har010',
#       u'@rel': u'related',
#       u'@title': u'doi'},
#      {u'@href': u'http://arxiv.org/abs/0903.5496v3',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/0903.5496v3',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2009-03-31T15:13:08Z',
#     u'summary': u'We use Higgs bundles to answer the following question: When can a maximal\nSp(4,R)-representation of a surface group be deformed to a representation which\nfactors through a proper reductive subgroup of Sp(4,R)?',
#     u'title': u'Deformations of maximal representations in Sp(4,R)',
#     u'updated': u'2010-06-07T07:30:49Z'},
#    {u'arxiv:comment': {u'#text': u'43 pages; v2: minor corrections and improvements, appendix\n  significantly shortened (the removed material will appear elsewhere); v3:\n  final version with many minor corrections and improvements, to appear in\n  Geometriae Dedicata',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois at Urbana-Champaign',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Steven B. Bradlow'},
#      {u'arxiv:affiliation': {u'#text': u'ICMAT-CSIC, Madrid',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Oscar Garcia-Prada'},
#      {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14H60 (Primary) 53C07, 58D29 (Secondary)'}],
#     u'id': u'http://arxiv.org/abs/1303.1058v3',
#     u'link': [{u'@href': u'http://arxiv.org/abs/1303.1058v3',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/1303.1058v3',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2013-03-05T15:05:48Z',
#     u'summary': u'Higgs bundles over a closed orientable surface can be defined for any real\nreductive Lie group G. In this paper we examine the case G=SO*(2n). We describe\na rigidity phenomenon encountered in the case of maximal Toledo invariant.\nUsing this and Morse theory in the moduli space of Higgs bundles, we show that\nthe moduli space is connected in this maximal Toledo case. The Morse theory\nalso allows us to show connectedness when the Toledo invariant is zero. The\ncorrespondence between Higgs bundles and surface group representations thus\nallows us to count the connected components with zero and maximal Toledo\ninvariant in the moduli space of representations of the fundamental group of\nthe surface in SO*(2n).',
#     u'title': u'Higgs bundles for the non-compact dual of the special orthogonal group',
#     u'updated': u'2014-10-16T14:57:58Z'},
#    {u'arxiv:comment': {u'#text': u'6 pages, to appear in C. R. Acad. Sci. Paris Ser. I Math',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:doi': {u'#text': u'10.1016/S0764-4442(01)02069-9',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:journal_ref': {u'#text': u"C. R. Acad. Sci. Paris S\\'er. I Math. 333 (2001), 347-352",
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Steven B. Bradlow'},
#      {u'arxiv:affiliation': {u'#text': u'Universidad Autonoma de Madrid',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Oscar Garcia-Prada'},
#      {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.RT'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14D20 (Primary) 14F45, 14H60, 32G13 (Secondary)'}],
#     u'id': u'http://arxiv.org/abs/math/0107103v1',
#     u'link': [{u'@href': u'http://dx.doi.org/10.1016/S0764-4442(01)02069-9',
#       u'@rel': u'related',
#       u'@title': u'doi'},
#      {u'@href': u'http://arxiv.org/abs/math/0107103v1',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0107103v1',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2001-07-13T10:01:35Z',
#     u'summary': u"We count the connected components in the moduli space of\nPU(p,q)-representations of the fundamental group for a closed oriented surface.\nThe components are labelled by pairs of integers which arise as topological\ninvariants of the flat bundles associated to the representations. Our results\nshow that for each allowed value of these invariants, which are bounded by a\nMilnor-Wood type inequality, there is a unique non-empty connected component.\nInterpreting the moduli space of representations as a moduli space of Higgs\nbundles, we take a Morse theoretic approach using a certain smooth proper\nfunction on the Higgs moduli space. A key step is the identification of the\nfunction's local minima as moduli spaces of holomorphic triples. We prove that\nthese moduli spaces of triples are non-empty and irreducible.",
#     u'title': u'Representations of the fundamental group of a surface in PU(p,q) and\n  holomorphic triples',
#     u'updated': u'2001-07-13T10:01:35Z'}],
#   u'id': u'http://arxiv.org/api/pG4cmntU0oTaAlHarLLoqS4Jr+s',
#   u'link': {u'@href': u'http://arxiv.org/api/query?search_query%3Dau%3ABradlow_S%26id_list%3D%26start%3D0%26max_results%3D1000',
#    u'@rel': u'self',
#    u'@type': u'application/atom+xml'},
#   u'opensearch:itemsPerPage': {u'#text': u'1000',
#    u'@xmlns:opensearch': u'http://a9.com/-/spec/opensearch/1.1/'},
#   u'opensearch:startIndex': {u'#text': u'0',
#    u'@xmlns:opensearch': u'http://a9.com/-/spec/opensearch/1.1/'},
#   u'opensearch:totalResults': {u'#text': u'24',
#    u'@xmlns:opensearch': u'http://a9.com/-/spec/opensearch/1.1/'},
#   u'title': {u'#text': u'ArXiv Query: search_query=au:Bradlow_S&id_list=&start=0&max_results=1000',
#    u'@type': u'html'},
#   u'updated': u'2016-03-29T00:00:00-04:00'}}

# %%
get_list(hold)
# Out:
# [{'authors': {u'name': u'Steven B. Bradlow'},
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/alg-geom/9506008v1',
#   'title': u'Steven B. BradlowHermitian-Einstein Inequalities and Harder-Narasimhan Filtration',
#   'year': 1995},
#  {'authors': [{u'name': u'S. Bradlow'},
#    {u'name': u'G. Daskalopoulos'},
#    {u'name': u'R. Wentworth'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/alg-geom/9304001v2',
#   'title': u'S. Bradlow; G. Daskalopoulos; R. Wentworth; Birational Equivalences of Vortex Moduli',
#   'year': 1993},
#  {'authors': [{u'name': u'Steven Bradlow'}, {u'name': u'Oscar Garcia-Prada'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/alg-geom/9602010v2',
#   'title': u'Steven Bradlow; Oscar Garcia-Prada; Non-abelian monopoles and vortices',
#   'year': 1996},
#  {'authors': [{u'name': u'Steven Bradlow'}, {u'name': u'Graeme Wilkin'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/1308.1460v1',
#   'title': u'Steven Bradlow; Graeme Wilkin; Morse Theory, Higgs fields and Yang-Mills-Higgs functionals',
#   'year': 2013},
#  {'authors': [{u'name': u'Steven B. Bradlow'},
#    {u'name': u'Oscar Garcia-Prada'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/alg-geom/9401008v2',
#   'title': u'Steven B. Bradlow; Oscar Garcia-Prada; Stable triples, equivariant bundles and dimensional reduction',
#   'year': 1994},
#  {'authors': [{u'name': u'Steven B. Bradlow'},
#    {u'name': u'Oscar Garcia-Prada'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/alg-geom/9506014v1',
#   'title': u'Steven B. Bradlow; Oscar Garcia-Prada; Higher cohomology triples and holomorphic extensions',
#   'year': 1995},
#  {'authors': [{u'name': u'Steven B. Bradlow'},
#    {u'name': u'Oscar Garcia-Prada'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/alg-geom/9602003v1',
#   'title': u'Steven B. Bradlow; Oscar Garcia-Prada; A Hitchin-Kobayashi Correspondence for Coherent Systems on Riemann\n  Surfaces',
#   'year': 1996},
#  {'authors': [{u'name': u'Steven Bradlow'},
#    {u'name': u'James Glazebrook'},
#    {u'name': u'Franz Kamber'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/alg-geom/9703019v1',
#   'title': u'Steven Bradlow; James Glazebrook; Franz Kamber; A New look at the vortex equations and dimensional reduction',
#   'year': 1997},
#  {'authors': [{u'name': u'Steven B. Bradlow'}, {u'name': u'Tomas L. Gomez'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/math/0009044v1',
#   'title': u'Steven B. Bradlow; Tomas L. Gomez; Extensions of Higgs Bundles',
#   'year': 2000},
#  {'authors': [{u'name': u'Steven Bradlow'},
#    {u'name': u'Oscar Garcia-Prada'},
#    {u'name': u'Vicente Mu\xf1oz'},
#    {u'name': u'Peter Newstead'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/math/0205317v1',
#   'title': u'Steven Bradlow; Oscar Garcia-Prada; Vicente Mu\xf1oz; Peter Newstead; Coherent systems and Brill-Noether theory',
#   'year': 2002},
#  {'authors': [{u'name': u'S. Bradlow'},
#    {u'name': u'O. Garcia-Prada'},
#    {u'name': u'V. Mercat'},
#    {u'name': u'V. Mu\xf1oz'},
#    {u'name': u'P. Newstead'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/math/0407523v5',
#   'title': u'S. Bradlow; O. Garcia-Prada; V. Mercat; V. Mu\xf1oz; P. Newstead; On the geometry of moduli spaces of coherent systems on algebraic curves',
#   'year': 2004},
#  {'authors': [{u'name': u'Steven B. Bradlow'},
#    {u'name': u'Laura P. Schaposnik'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/1508.02650v2',
#   'title': u'Steven B. Bradlow; Laura P. Schaposnik; Higgs bundles and exceptional isogenies',
#   'year': 2015},
#  {'authors': [{u'name': u'Steven B. Bradlow'},
#    {u'name': u'Oscar Garcia-Prada'},
#    {u'name': u'Peter B. Gothen'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/math/0206012v1',
#   'title': u'Steven B. Bradlow; Oscar Garcia-Prada; Peter B. Gothen; Surface group representations, Higgs bundles, and holomorphic triples',
#   'year': 2002},
#  {'authors': [{u'name': u'S. B. Bradlow'},
#    {u'name': u'O. Garcia-Prada'},
#    {u'name': u'V. Mercat'},
#    {u'name': u'V. Munoz'},
#    {u'name': u'P. E. Newstead'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/0707.0983v2',
#   'title': u'S. B. Bradlow; O. Garcia-Prada; V. Mercat; V. Munoz; P. E. Newstead; Moduli spaces of coherent systems of small slope on algebraic curves',
#   'year': 2007},
#  {'authors': [{u'name': u'Steven B. Bradlow'},
#    {u'name': u'Oscar Garcia-Prada'},
#    {u'name': u'Ignasi Mundet i Rierra'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/math/0206003v1',
#   'title': u'Steven B. Bradlow; Oscar Garcia-Prada; Ignasi Mundet i Rierra; Relative Hitchin--Kobayashi correspondences for principal pairs',
#   'year': 2002},
#  {'authors': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/math/0211428v2',
#   'title': u'Steven B. Bradlow; Oscar Garcia-Prada; Peter B. Gothen; Moduli spaces of holomorphic triples over compact Riemann surfaces',
#   'year': 2002},
#  {'authors': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/math/0211431v3',
#   'title': u'Steven B. Bradlow; Oscar Garcia-Prada; Peter B. Gothen; Surface group representations in PU(p,q) and Higgs bundles',
#   'year': 2002},
#  {'authors': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'IMAFF, CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/math/0401064v2',
#   'title': u'Steven B. Bradlow; Oscar Garcia-Prada; Peter B. Gothen; Representations of surface groups in the general linear group',
#   'year': 2004},
#  {'authors': [{u'name': u'Steven B. Bradlow'},
#    {u'name': u'James F. Glazebrook'},
#    {u'name': u'Franz W. Kamber'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/math/0405205v1',
#   'title': u'Steven B. Bradlow; James F. Glazebrook; Franz W. Kamber; Dimensional reduction of the perturbed Hermitian-Einstein equation',
#   'year': 2004},
#  {'authors': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/math/0506444v4',
#   'title': u'Steven B. Bradlow; Oscar Garcia-Prada; Peter B. Gothen; Homotopy groups of moduli spaces of representations',
#   'year': 2005},
#  {'authors': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/math/0511415v3',
#   'title': u'Steven B. Bradlow; Oscar Garcia-Prada; Peter B. Gothen; Maximal surface group representations in isometry groups of classical\n  Hermitian symmetric spaces',
#   'year': 2005},
#  {'authors': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/0903.5496v3',
#   'title': u'Steven B. Bradlow; Oscar Garcia-Prada; Peter B. Gothen; Deformations of maximal representations in Sp(4,R)',
#   'year': 2009},
#  {'authors': [{u'arxiv:affiliation': {u'#text': u'University of Illinois at Urbana-Champaign',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'ICMAT-CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/1303.1058v3',
#   'title': u'Steven B. Bradlow; Oscar Garcia-Prada; Peter B. Gothen; Higgs bundles for the non-compact dual of the special orthogonal group',
#   'year': 2013},
#  {'authors': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'Universidad Autonoma de Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   'collaborators': [],
#   'id': u'http://arxiv.org/abs/math/0107103v1',
#   'title': u'Steven B. Bradlow; Oscar Garcia-Prada; Peter B. Gothen; Representations of the fundamental group of a surface in PU(p,q) and\n  holomorphic triples',
#   'year': 2001}]

# %%
def extract_year(time_string):
    return dateutil.parser.parse(time_string).year
