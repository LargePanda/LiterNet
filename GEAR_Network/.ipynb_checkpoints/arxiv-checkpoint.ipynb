# %%
import xml.etree.ElementTree as ET
from fuzzywuzzy import fuzz
import json
import xmltodict

# %%
def if_same_person(first, second):

    ser = fuzz.token_set_ratio(first, second)    

    return ser > 75

# %%
import urllib
url = 'http://export.arxiv.org/api/query?search_query=au:Bradlow_Steven AND au:Gothen_Peter'
data = urllib.urlopen(url).read()
print data
# Out:
# <?xml version="1.0" encoding="UTF-8"?>
# <feed xmlns="http://www.w3.org/2005/Atom">
#   <link href="http://arxiv.org/api/query?search_query%3Dau%3ABradlow_Steven%20AND%20au%3AGothen_Peter%26id_list%3D%26start%3D0%26max_results%3D10" rel="self" type="application/atom+xml"/>
#   <title type="html">ArXiv Query: search_query=au:Bradlow_Steven AND au:Gothen_Peter&amp;id_list=&amp;start=0&amp;max_results=10</title>
#   <id>http://arxiv.org/api/Uc2h2SPcjv6bjYdlL6QsWgtZgTY</id>
#   <updated>2016-03-15T00:00:00-04:00</updated>
#   <opensearch:totalResults xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">9</opensearch:totalResults>
#   <opensearch:startIndex xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">0</opensearch:startIndex>
#   <opensearch:itemsPerPage xmlns:opensearch="http://a9.com/-/spec/opensearch/1.1/">10</opensearch:itemsPerPage>
#   <entry>
#     <id>http://arxiv.org/abs/math/0206012v1</id>
#     <updated>2002-06-03T13:23:50Z</updated>
#     <published>2002-06-03T13:23:50Z</published>
#     <title>Surface group representations, Higgs bundles, and holomorphic triples</title>
#     <summary>  Using the $L^2$ norm of the Higgs field as a Morse function, we study the
# moduli spaces of $U(p,q)$-Higgs bundles over a Riemann surface. We require that
# the genus of the surface be at least two, but place no constraints on $(p,q)$.
# A key step is the identification of the function's local minima as moduli
# spaces of holomorphic triples. We prove that these moduli spaces of triples are
# irreducible and non-empty.
#   Because of the relation between flat bundles and fundamental group
# representations, we can interpret our conclusions as results about the number
# of connected components in the moduli space of semisimple
# $PU(p,q)$-representations. The topological invariants of the flat bundles
# bundle are used to label components. These invariants are bounded by a
# Milnor-Wood type inequality. For each allowed value of the invariants
# satisfying a certain coprimality condition, we prove that the corresponding
# component is non-empty and connected. If the coprimality condition does not
# hold, our results apply to the irreducible representations.
# </summary>
#     <author>
#       <name>Steven B. Bradlow</name>
#     </author>
#     <author>
#       <name>Oscar Garcia-Prada</name>
#     </author>
#     <author>
#       <name>Peter B. Gothen</name>
#     </author>
#     <arxiv:comment xmlns:arxiv="http://arxiv.org/schemas/atom">106 pages</arxiv:comment>
#     <link href="http://arxiv.org/abs/math/0206012v1" rel="alternate" type="text/html"/>
#     <link title="pdf" href="http://arxiv.org/pdf/math/0206012v1" rel="related" type="application/pdf"/>
#     <arxiv:primary_category xmlns:arxiv="http://arxiv.org/schemas/atom" term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="14H30, 14H60, 32L05" scheme="http://arxiv.org/schemas/atom"/>
#   </entry>
#   <entry>
#     <id>http://arxiv.org/abs/math/0211428v2</id>
#     <updated>2003-10-02T09:13:55Z</updated>
#     <published>2002-11-27T15:06:44Z</published>
#     <title>Moduli spaces of holomorphic triples over compact Riemann surfaces</title>
#     <summary>  A holomorphic triple over a compact Riemann surface consists of two
# holomorphic vector bundles and a holomorphic map between them. After fixing the
# topological types of the bundles and a real parameter, there exist moduli
# spaces of stable holomorphic triples. In this paper we study non-emptiness,
# irreducibility, smoothness, and birational descriptions of these moduli spaces
# for a certain range of the parameter. Our results have important applications
# to the study of the moduli space of representations of the fundamental group of
# the surface into unitary Lie groups of indefinite signature, which we explore
# in a companion paper "Surface group representations in PU(p,q) and Higgs
# bundles". Another application, that we study in this paper, is to the existence
# of stable bundles on the product of the surface by the complex projective line.
#  This paper, and its companion mentioned above, form a substantially revised
# version of math.AG/0206012.
# </summary>
#     <author>
#       <name>Steven B. Bradlow</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">University of Illinois</arxiv:affiliation>
#     </author>
#     <author>
#       <name>Oscar Garcia-Prada</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">CSIC, Madrid</arxiv:affiliation>
#     </author>
#     <author>
#       <name>Peter B. Gothen</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">Universidade do Porto</arxiv:affiliation>
#     </author>
#     <arxiv:doi xmlns:arxiv="http://arxiv.org/schemas/atom">10.1007/s00208-003-0484-z</arxiv:doi>
#     <link title="doi" href="http://dx.doi.org/10.1007/s00208-003-0484-z" rel="related"/>
#     <arxiv:comment xmlns:arxiv="http://arxiv.org/schemas/atom">44 pages. v2: minor clarifications and corrections, to appear in
#   Math. Annalen</arxiv:comment>
#     <arxiv:journal_ref xmlns:arxiv="http://arxiv.org/schemas/atom">Math. Ann. 328 (2004), 299-351.</arxiv:journal_ref>
#     <link href="http://arxiv.org/abs/math/0211428v2" rel="alternate" type="text/html"/>
#     <link title="pdf" href="http://arxiv.org/pdf/math/0211428v2" rel="related" type="application/pdf"/>
#     <arxiv:primary_category xmlns:arxiv="http://arxiv.org/schemas/atom" term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.DG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="14D20 (Primary) 14H60, 32G13 (Secondary)" scheme="http://arxiv.org/schemas/atom"/>
#   </entry>
#   <entry>
#     <id>http://arxiv.org/abs/math/0211431v3</id>
#     <updated>2003-07-11T08:54:37Z</updated>
#     <published>2002-11-27T15:31:01Z</published>
#     <title>Surface group representations in PU(p,q) and Higgs bundles</title>
#     <summary>  Using the L^2 norm of the Higgs field as a Morse function, we study the
# moduli spaces of U(p,q)-Higgs bundles over a Riemann surface. We require that
# the genus of the surface be at least two, but place no constraints on (p,q). A
# key step is the identification of the function's local minima as moduli spaces
# of holomorphic triples. In a companion paper "Moduli spaces of holomorphic
# triples over compact Riemann surfaces" (math.AG/0211428) we prove that these
# moduli spaces of triples are non-empty and irreducible.
#  Because of the relation between flat bundles and fundamental group
# representations, we can interpret our conclusions as results about the number
# of connected components in the moduli space of semisimple
# PU(p,q)-representations. The topological invariants of the flat bundles are
# used to label subspaces. These invariants are bounded by a Milnor-Wood type
# inequality. For each allowed value of the invariants satisfying a certain
# coprimality condition, we prove that the corresponding subspace is non-empty
# and connected. If the coprimality condition does not hold, our results apply to
# the closure of the moduli space of irreducible representations.
#  This paper, and its companion mentioned above, form a substantially revised
# version of math.AG/0206012.
# </summary>
#     <author>
#       <name>Steven B. Bradlow</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">University of Illinois</arxiv:affiliation>
#     </author>
#     <author>
#       <name>Oscar Garcia-Prada</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">CSIC, Madrid</arxiv:affiliation>
#     </author>
#     <author>
#       <name>Peter B. Gothen</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">Universidade do Porto</arxiv:affiliation>
#     </author>
#     <arxiv:comment xmlns:arxiv="http://arxiv.org/schemas/atom">44 pages, 2 figures. Minor clarifications and corrections. Final
#   version, to appear in J. Diff. Geom</arxiv:comment>
#     <arxiv:journal_ref xmlns:arxiv="http://arxiv.org/schemas/atom">J. Diff. Geom. 64 (2003), 111-170.</arxiv:journal_ref>
#     <link href="http://arxiv.org/abs/math/0211431v3" rel="alternate" type="text/html"/>
#     <link title="pdf" href="http://arxiv.org/pdf/math/0211431v3" rel="related" type="application/pdf"/>
#     <arxiv:primary_category xmlns:arxiv="http://arxiv.org/schemas/atom" term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.DG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="14D20 (Primary) 14H60, 32G13 (Secondary)" scheme="http://arxiv.org/schemas/atom"/>
#   </entry>
#   <entry>
#     <id>http://arxiv.org/abs/math/0401064v2</id>
#     <updated>2004-01-19T11:28:48Z</updated>
#     <published>2004-01-07T17:29:15Z</published>
#     <title>Representations of surface groups in the general linear group</title>
#     <summary>  We determine the number of connected components of the moduli space for
# representations of a surface group in the general linear group.
# </summary>
#     <author>
#       <name>Steven B. Bradlow</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">University of Illinois</arxiv:affiliation>
#     </author>
#     <author>
#       <name>Oscar Garcia-Prada</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">IMAFF, CSIC, Madrid</arxiv:affiliation>
#     </author>
#     <author>
#       <name>Peter B. Gothen</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">Universidade do Porto</arxiv:affiliation>
#     </author>
#     <arxiv:comment xmlns:arxiv="http://arxiv.org/schemas/atom">12 pages. v2: corrected statement of Theorem 5.2 (1), other minor
#   corrections. To appear in the Proceedings of the Fall Workshop on Geometry
#   and Physics, Coimbra 2003</arxiv:comment>
#     <arxiv:journal_ref xmlns:arxiv="http://arxiv.org/schemas/atom">Proceedings of the XII Fall Workshop on Geometry and Physics,
#   Coimbra 2003, Publicaciones de la RSME 7 (2004), 83-94</arxiv:journal_ref>
#     <link href="http://arxiv.org/abs/math/0401064v2" rel="alternate" type="text/html"/>
#     <link title="pdf" href="http://arxiv.org/pdf/math/0401064v2" rel="related" type="application/pdf"/>
#     <arxiv:primary_category xmlns:arxiv="http://arxiv.org/schemas/atom" term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.DG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="14D20, 14F45, 14H60" scheme="http://arxiv.org/schemas/atom"/>
#   </entry>
#   <entry>
#     <id>http://arxiv.org/abs/math/0506444v4</id>
#     <updated>2007-06-14T09:57:44Z</updated>
#     <published>2005-06-22T10:49:12Z</published>
#     <title>Homotopy groups of moduli spaces of representations</title>
#     <summary>  We calculate certain homotopy groups of the moduli spaces for representations
# of a compact oriented surface in the Lie groups GL(n,C) and U(p,q). Our
# approach relies on the interpretation of these representations in terms of
# Higgs bundles and uses Bott--Morse theory on the corresponding moduli spaces.
# </summary>
#     <author>
#       <name>Steven B. Bradlow</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">University of Illinois</arxiv:affiliation>
#     </author>
#     <author>
#       <name>Oscar Garcia-Prada</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">CSIC, Madrid</arxiv:affiliation>
#     </author>
#     <author>
#       <name>Peter B. Gothen</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">Universidade do Porto</arxiv:affiliation>
#     </author>
#     <arxiv:doi xmlns:arxiv="http://arxiv.org/schemas/atom">10.1016/j.top.2007.06.001</arxiv:doi>
#     <link title="doi" href="http://dx.doi.org/10.1016/j.top.2007.06.001" rel="related"/>
#     <arxiv:comment xmlns:arxiv="http://arxiv.org/schemas/atom">21 pages; v2: improved results for moduli of representations in
#   GL(n,C), provided proof of Proposition 4.13 (4.12 of v1) correcting argument
#   given in earlier paper, other minor corrections; v3: corrected Remark 4.6,
#   other minor corrections; v4: corrected statements of Proposition 4.17 and
#   Theorems 4.19 and 4.22 (former Theorems 4.18 and 4.20); to appear in Topology</arxiv:comment>
#     <arxiv:journal_ref xmlns:arxiv="http://arxiv.org/schemas/atom">Topology 47 (2008), 203-224</arxiv:journal_ref>
#     <link href="http://arxiv.org/abs/math/0506444v4" rel="alternate" type="text/html"/>
#     <link title="pdf" href="http://arxiv.org/pdf/math/0506444v4" rel="related" type="application/pdf"/>
#     <arxiv:primary_category xmlns:arxiv="http://arxiv.org/schemas/atom" term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.DG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="14H60, 57R57, 58D29" scheme="http://arxiv.org/schemas/atom"/>
#   </entry>
#   <entry>
#     <id>http://arxiv.org/abs/math/0511415v3</id>
#     <updated>2006-11-27T11:57:56Z</updated>
#     <published>2005-11-16T16:07:34Z</published>
#     <title>Maximal surface group representations in isometry groups of classical
#   Hermitian symmetric spaces</title>
#     <summary>  Higgs bundles and non-abelian Hodge theory provide holomorphic methods with
# which to study the moduli spaces of surface group representations in a
# reductive Lie group G. In this paper we survey the case in which G is the
# isometry group of a classical Hermitian symmetric space of non-compact type.
# Using Morse theory on the moduli spaces of Higgs bundles, we compute the number
# of connected components of the moduli space of representations with maximal
# Toledo invariant.
# </summary>
#     <author>
#       <name>Steven B. Bradlow</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">University of Illinois</arxiv:affiliation>
#     </author>
#     <author>
#       <name>Oscar Garcia-Prada</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">CSIC, Madrid</arxiv:affiliation>
#     </author>
#     <author>
#       <name>Peter B. Gothen</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">Universidade do Porto</arxiv:affiliation>
#     </author>
#     <arxiv:doi xmlns:arxiv="http://arxiv.org/schemas/atom">10.1007/s10711-007-9127-y</arxiv:doi>
#     <link title="doi" href="http://dx.doi.org/10.1007/s10711-007-9127-y" rel="related"/>
#     <arxiv:comment xmlns:arxiv="http://arxiv.org/schemas/atom">v2: added due credits to the work of Burger, Iozzi and Wienhard. v3:
#   corrected count of connected components for G=SU(p,q) (p \neq q); added due
#   credits to the work of Xia and Markman-Xia; minor corrections and
#   clarifications. 31 pages</arxiv:comment>
#     <arxiv:journal_ref xmlns:arxiv="http://arxiv.org/schemas/atom">Geometriae Dedicata 122 (2006), 185-213</arxiv:journal_ref>
#     <link href="http://arxiv.org/abs/math/0511415v3" rel="alternate" type="text/html"/>
#     <link title="pdf" href="http://arxiv.org/pdf/math/0511415v3" rel="related" type="application/pdf"/>
#     <arxiv:primary_category xmlns:arxiv="http://arxiv.org/schemas/atom" term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.DG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="14H60 (Primary) 57R57, 58D29 (Secondary)" scheme="http://arxiv.org/schemas/atom"/>
#   </entry>
#   <entry>
#     <id>http://arxiv.org/abs/0903.5496v3</id>
#     <updated>2010-06-07T07:30:49Z</updated>
#     <published>2009-03-31T15:13:08Z</published>
#     <title>Deformations of maximal representations in Sp(4,R)</title>
#     <summary>  We use Higgs bundles to answer the following question: When can a maximal
# Sp(4,R)-representation of a surface group be deformed to a representation which
# factors through a proper reductive subgroup of Sp(4,R)?
# </summary>
#     <author>
#       <name>Steven B. Bradlow</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">University of Illinois</arxiv:affiliation>
#     </author>
#     <author>
#       <name>Oscar Garcia-Prada</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">CSIC, Madrid</arxiv:affiliation>
#     </author>
#     <author>
#       <name>Peter B. Gothen</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">Universidade do Porto</arxiv:affiliation>
#     </author>
#     <arxiv:doi xmlns:arxiv="http://arxiv.org/schemas/atom">10.1093/qmath/har010</arxiv:doi>
#     <link title="doi" href="http://dx.doi.org/10.1093/qmath/har010" rel="related"/>
#     <arxiv:comment xmlns:arxiv="http://arxiv.org/schemas/atom">49 pages; v2: various improvements and minor corrections; v3:
#   improved exposition</arxiv:comment>
#     <arxiv:journal_ref xmlns:arxiv="http://arxiv.org/schemas/atom">Q. J. Math. 63 (2012), 795-843</arxiv:journal_ref>
#     <link href="http://arxiv.org/abs/0903.5496v3" rel="alternate" type="text/html"/>
#     <link title="pdf" href="http://arxiv.org/pdf/0903.5496v3" rel="related" type="application/pdf"/>
#     <arxiv:primary_category xmlns:arxiv="http://arxiv.org/schemas/atom" term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.DG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="14H60 (Primary) 57M99, 22E99 (Secondary)" scheme="http://arxiv.org/schemas/atom"/>
#   </entry>
#   <entry>
#     <id>http://arxiv.org/abs/1303.1058v3</id>
#     <updated>2014-10-16T14:57:58Z</updated>
#     <published>2013-03-05T15:05:48Z</published>
#     <title>Higgs bundles for the non-compact dual of the special orthogonal group</title>
#     <summary>  Higgs bundles over a closed orientable surface can be defined for any real
# reductive Lie group G. In this paper we examine the case G=SO*(2n). We describe
# a rigidity phenomenon encountered in the case of maximal Toledo invariant.
# Using this and Morse theory in the moduli space of Higgs bundles, we show that
# the moduli space is connected in this maximal Toledo case. The Morse theory
# also allows us to show connectedness when the Toledo invariant is zero. The
# correspondence between Higgs bundles and surface group representations thus
# allows us to count the connected components with zero and maximal Toledo
# invariant in the moduli space of representations of the fundamental group of
# the surface in SO*(2n).
# </summary>
#     <author>
#       <name>Steven B. Bradlow</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">University of Illinois at Urbana-Champaign</arxiv:affiliation>
#     </author>
#     <author>
#       <name>Oscar Garcia-Prada</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">ICMAT-CSIC, Madrid</arxiv:affiliation>
#     </author>
#     <author>
#       <name>Peter B. Gothen</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">Universidade do Porto</arxiv:affiliation>
#     </author>
#     <arxiv:comment xmlns:arxiv="http://arxiv.org/schemas/atom">43 pages; v2: minor corrections and improvements, appendix
#   significantly shortened (the removed material will appear elsewhere); v3:
#   final version with many minor corrections and improvements, to appear in
#   Geometriae Dedicata</arxiv:comment>
#     <link href="http://arxiv.org/abs/1303.1058v3" rel="alternate" type="text/html"/>
#     <link title="pdf" href="http://arxiv.org/pdf/1303.1058v3" rel="related" type="application/pdf"/>
#     <arxiv:primary_category xmlns:arxiv="http://arxiv.org/schemas/atom" term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.DG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="14H60 (Primary) 53C07, 58D29 (Secondary)" scheme="http://arxiv.org/schemas/atom"/>
#   </entry>
#   <entry>
#     <id>http://arxiv.org/abs/math/0107103v1</id>
#     <updated>2001-07-13T10:01:35Z</updated>
#     <published>2001-07-13T10:01:35Z</published>
#     <title>Representations of the fundamental group of a surface in PU(p,q) and
#   holomorphic triples</title>
#     <summary>  We count the connected components in the moduli space of
# PU(p,q)-representations of the fundamental group for a closed oriented surface.
# The components are labelled by pairs of integers which arise as topological
# invariants of the flat bundles associated to the representations. Our results
# show that for each allowed value of these invariants, which are bounded by a
# Milnor-Wood type inequality, there is a unique non-empty connected component.
# Interpreting the moduli space of representations as a moduli space of Higgs
# bundles, we take a Morse theoretic approach using a certain smooth proper
# function on the Higgs moduli space. A key step is the identification of the
# function's local minima as moduli spaces of holomorphic triples. We prove that
# these moduli spaces of triples are non-empty and irreducible.
# </summary>
#     <author>
#       <name>Steven B. Bradlow</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">University of Illinois</arxiv:affiliation>
#     </author>
#     <author>
#       <name>Oscar Garcia-Prada</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">Universidad Autonoma de Madrid</arxiv:affiliation>
#     </author>
#     <author>
#       <name>Peter B. Gothen</name>
#       <arxiv:affiliation xmlns:arxiv="http://arxiv.org/schemas/atom">Universidade do Porto</arxiv:affiliation>
#     </author>
#     <arxiv:doi xmlns:arxiv="http://arxiv.org/schemas/atom">10.1016/S0764-4442(01)02069-9</arxiv:doi>
#     <link title="doi" href="http://dx.doi.org/10.1016/S0764-4442(01)02069-9" rel="related"/>
#     <arxiv:comment xmlns:arxiv="http://arxiv.org/schemas/atom">6 pages, to appear in C. R. Acad. Sci. Paris Ser. I Math</arxiv:comment>
#     <arxiv:journal_ref xmlns:arxiv="http://arxiv.org/schemas/atom">C. R. Acad. Sci. Paris S\'er. I Math. 333 (2001), 347-352</arxiv:journal_ref>
#     <link href="http://arxiv.org/abs/math/0107103v1" rel="alternate" type="text/html"/>
#     <link title="pdf" href="http://arxiv.org/pdf/math/0107103v1" rel="related" type="application/pdf"/>
#     <arxiv:primary_category xmlns:arxiv="http://arxiv.org/schemas/atom" term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.AG" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="math.RT" scheme="http://arxiv.org/schemas/atom"/>
#     <category term="14D20 (Primary) 14F45, 14H60, 32G13 (Secondary)" scheme="http://arxiv.org/schemas/atom"/>
#   </entry>
# </feed>

# %%
def possibles(fn, ln):
    ret = [ln+"_"+fn, ln+"_"+fn[0], fn+"_"+ln]
    return ret

# %%
def combines(a_first_name, a_last_name, b_first_name, b_last_name):
    cl1 = possibles(a_first_name, a_last_name)
    cl2 = possibles(b_first_name, b_last_name)
    ret = []
    for c1 in cl1:
        for c2 in cl2:
            ret.append((c1, c2))
    return ret

# %%
def build_url(n1, n2):
    url = "http://export.arxiv.org/api/query?search_query=au:"
    url += n1 +" AND " + "au:"+n2 + "&max_results=1000"
    return url

# %%
def get_list(src, p1, p2):
    ret = []
    try:
        for entry in src['feed'][u'entry']:
            unit = {}
            unit['title'] = entry['title']
            unit['authors'] = entry['author']

            score = 0
            for author in unit['authors']:
                if if_same_person(p1, author['name']) or if_same_person(p2, author['name']):
                    score += 1 
            unit['id'] = entry['id']
            ret.append(unit)
    except:
        pass
    return ret

# %%
def get_papers(a_first_name, a_last_name, b_first_name, b_last_name):
    comb = combines(a_first_name, a_last_name, b_first_name, b_last_name)
    print comb
    col = {}
    for c in comb:
        url = build_url(c[0], c[1])
        print url
        data = urllib.urlopen(url).read()
        hold = json.loads(json.dumps(xmltodict.parse(data)))
        papers = get_list(hold, a_first_name+" "+a_last_name, b_first_name+" "+b_last_name)
        for paper in papers:
            idea = paper['id']
            col[idea] = paper
    return col

# %%
get_papers("Steven", "Bradlow", "Gothen", "Peter")
# Out:
# [('Bradlow_Steven', 'Peter_Gothen'), ('Bradlow_Steven', 'Peter_G'), ('Bradlow_Steven', 'Gothen_Peter'), ('Bradlow_S', 'Peter_Gothen'), ('Bradlow_S', 'Peter_G'), ('Bradlow_S', 'Gothen_Peter'), ('Steven_Bradlow', 'Peter_Gothen'), ('Steven_Bradlow', 'Peter_G'), ('Steven_Bradlow', 'Gothen_Peter')]
# http://export.arxiv.org/api/query?search_query=au:Bradlow_Steven AND au:Peter_Gothen&max_results=1000
# http://export.arxiv.org/api/query?search_query=au:Bradlow_Steven AND au:Peter_G&max_results=1000
# http://export.arxiv.org/api/query?search_query=au:Bradlow_Steven AND au:Gothen_Peter&max_results=1000
# good
# good
# good
# good
# good
# good
# good
# good
# good
# {'authors': [{u'name': u'Steven B. Bradlow'}, {u'name': u'Oscar Garcia-Prada'}, {u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/math/0206012v1', 'title': u'Surface group representations, Higgs bundles, and holomorphic triples'}
# {'authors': [{u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'University of Illinois'}, u'name': u'Steven B. Bradlow'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'CSIC, Madrid'}, u'name': u'Oscar Garcia-Prada'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidade do Porto'}, u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/math/0211428v2', 'title': u'Moduli spaces of holomorphic triples over compact Riemann surfaces'}
# {'authors': [{u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'University of Illinois'}, u'name': u'Steven B. Bradlow'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'CSIC, Madrid'}, u'name': u'Oscar Garcia-Prada'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidade do Porto'}, u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/math/0211431v3', 'title': u'Surface group representations in PU(p,q) and Higgs bundles'}
# {'authors': [{u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'University of Illinois'}, u'name': u'Steven B. Bradlow'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'IMAFF, CSIC, Madrid'}, u'name': u'Oscar Garcia-Prada'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidade do Porto'}, u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/math/0401064v2', 'title': u'Representations of surface groups in the general linear group'}
# {'authors': [{u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'University of Illinois'}, u'name': u'Steven B. Bradlow'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'CSIC, Madrid'}, u'name': u'Oscar Garcia-Prada'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidade do Porto'}, u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/math/0506444v4', 'title': u'Homotopy groups of moduli spaces of representations'}
# {'authors': [{u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'University of Illinois'}, u'name': u'Steven B. Bradlow'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'CSIC, Madrid'}, u'name': u'Oscar Garcia-Prada'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidade do Porto'}, u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/math/0511415v3', 'title': u'Maximal surface group representations in isometry groups of classical\n  Hermitian symmetric spaces'}
# {'authors': [{u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'University of Illinois'}, u'name': u'Steven B. Bradlow'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'CSIC, Madrid'}, u'name': u'Oscar Garcia-Prada'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidade do Porto'}, u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/0903.5496v3', 'title': u'Deformations of maximal representations in Sp(4,R)'}
# {'authors': [{u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'University of Illinois at Urbana-Champaign'}, u'name': u'Steven B. Bradlow'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'ICMAT-CSIC, Madrid'}, u'name': u'Oscar Garcia-Prada'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidade do Porto'}, u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/1303.1058v3', 'title': u'Higgs bundles for the non-compact dual of the special orthogonal group'}
# {'authors': [{u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'University of Illinois'}, u'name': u'Steven B. Bradlow'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidad Autonoma de Madrid'}, u'name': u'Oscar Garcia-Prada'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidade do Porto'}, u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/math/0107103v1', 'title': u'Representations of the fundamental group of a surface in PU(p,q) and\n  holomorphic triples'}
# http://export.arxiv.org/api/query?search_query=au:Bradlow_S AND au:Peter_Gothen&max_results=1000
# http://export.arxiv.org/api/query?search_query=au:Bradlow_S AND au:Peter_G&max_results=1000
# http://export.arxiv.org/api/query?search_query=au:Bradlow_S AND au:Gothen_Peter&max_results=1000
# good
# good
# good
# good
# good
# good
# good
# good
# good
# {'authors': [{u'name': u'Steven B. Bradlow'}, {u'name': u'Oscar Garcia-Prada'}, {u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/math/0206012v1', 'title': u'Surface group representations, Higgs bundles, and holomorphic triples'}
# {'authors': [{u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'University of Illinois'}, u'name': u'Steven B. Bradlow'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'CSIC, Madrid'}, u'name': u'Oscar Garcia-Prada'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidade do Porto'}, u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/math/0211428v2', 'title': u'Moduli spaces of holomorphic triples over compact Riemann surfaces'}
# {'authors': [{u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'University of Illinois'}, u'name': u'Steven B. Bradlow'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'CSIC, Madrid'}, u'name': u'Oscar Garcia-Prada'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidade do Porto'}, u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/math/0211431v3', 'title': u'Surface group representations in PU(p,q) and Higgs bundles'}
# {'authors': [{u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'University of Illinois'}, u'name': u'Steven B. Bradlow'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'IMAFF, CSIC, Madrid'}, u'name': u'Oscar Garcia-Prada'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidade do Porto'}, u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/math/0401064v2', 'title': u'Representations of surface groups in the general linear group'}
# {'authors': [{u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'University of Illinois'}, u'name': u'Steven B. Bradlow'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'CSIC, Madrid'}, u'name': u'Oscar Garcia-Prada'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidade do Porto'}, u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/math/0506444v4', 'title': u'Homotopy groups of moduli spaces of representations'}
# {'authors': [{u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'University of Illinois'}, u'name': u'Steven B. Bradlow'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'CSIC, Madrid'}, u'name': u'Oscar Garcia-Prada'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidade do Porto'}, u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/math/0511415v3', 'title': u'Maximal surface group representations in isometry groups of classical\n  Hermitian symmetric spaces'}
# {'authors': [{u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'University of Illinois'}, u'name': u'Steven B. Bradlow'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'CSIC, Madrid'}, u'name': u'Oscar Garcia-Prada'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidade do Porto'}, u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/0903.5496v3', 'title': u'Deformations of maximal representations in Sp(4,R)'}
# {'authors': [{u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'University of Illinois at Urbana-Champaign'}, u'name': u'Steven B. Bradlow'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'ICMAT-CSIC, Madrid'}, u'name': u'Oscar Garcia-Prada'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidade do Porto'}, u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/1303.1058v3', 'title': u'Higgs bundles for the non-compact dual of the special orthogonal group'}
# {'authors': [{u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'University of Illinois'}, u'name': u'Steven B. Bradlow'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidad Autonoma de Madrid'}, u'name': u'Oscar Garcia-Prada'}, {u'arxiv:affiliation': {u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom', u'#text': u'Universidade do Porto'}, u'name': u'Peter B. Gothen'}], 'id': u'http://arxiv.org/abs/math/0107103v1', 'title': u'Representations of the fundamental group of a surface in PU(p,q) and\n  holomorphic triples'}
# http://export.arxiv.org/api/query?search_query=au:Steven_Bradlow AND au:Peter_Gothen&max_results=1000
# http://export.arxiv.org/api/query?search_query=au:Steven_Bradlow AND au:Peter_G&max_results=1000
# http://export.arxiv.org/api/query?search_query=au:Steven_Bradlow AND au:Gothen_Peter&max_results=1000
# {u'http://arxiv.org/abs/0903.5496v3': {'authors': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   'id': u'http://arxiv.org/abs/0903.5496v3',
#   'title': u'Deformations of maximal representations in Sp(4,R)'},
#  u'http://arxiv.org/abs/1303.1058v3': {'authors': [{u'arxiv:affiliation': {u'#text': u'University of Illinois at Urbana-Champaign',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'ICMAT-CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   'id': u'http://arxiv.org/abs/1303.1058v3',
#   'title': u'Higgs bundles for the non-compact dual of the special orthogonal group'},
#  u'http://arxiv.org/abs/math/0107103v1': {'authors': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'Universidad Autonoma de Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   'id': u'http://arxiv.org/abs/math/0107103v1',
#   'title': u'Representations of the fundamental group of a surface in PU(p,q) and\n  holomorphic triples'},
#  u'http://arxiv.org/abs/math/0206012v1': {'authors': [{u'name': u'Steven B. Bradlow'},
#    {u'name': u'Oscar Garcia-Prada'},
#    {u'name': u'Peter B. Gothen'}],
#   'id': u'http://arxiv.org/abs/math/0206012v1',
#   'title': u'Surface group representations, Higgs bundles, and holomorphic triples'},
#  u'http://arxiv.org/abs/math/0211428v2': {'authors': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   'id': u'http://arxiv.org/abs/math/0211428v2',
#   'title': u'Moduli spaces of holomorphic triples over compact Riemann surfaces'},
#  u'http://arxiv.org/abs/math/0211431v3': {'authors': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   'id': u'http://arxiv.org/abs/math/0211431v3',
#   'title': u'Surface group representations in PU(p,q) and Higgs bundles'},
#  u'http://arxiv.org/abs/math/0401064v2': {'authors': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'IMAFF, CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   'id': u'http://arxiv.org/abs/math/0401064v2',
#   'title': u'Representations of surface groups in the general linear group'},
#  u'http://arxiv.org/abs/math/0506444v4': {'authors': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   'id': u'http://arxiv.org/abs/math/0506444v4',
#   'title': u'Homotopy groups of moduli spaces of representations'},
#  u'http://arxiv.org/abs/math/0511415v3': {'authors': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   'id': u'http://arxiv.org/abs/math/0511415v3',
#   'title': u'Maximal surface group representations in isometry groups of classical\n  Hermitian symmetric spaces'}}

# %%
get_list("http://export.arxiv.org/api/query?search_query=au:Bradlow_Steven AND au:Gothen_Peter&max_results=1000", "1", "2")
# Out:
# []

# %%
url = "http://export.arxiv.org/api/query?search_query=au:Bradlow_Steven AND au:Gothen_Peter&max_results=1000"

# %%
data = urllib.urlopen(url).read()

# %%
hold = json.loads(json.dumps(xmltodict.parse(data)))

# %%
hold
# Out:
# {u'feed': {u'@xmlns': u'http://www.w3.org/2005/Atom',
#   u'entry': [{u'arxiv:comment': {u'#text': u'106 pages',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'name': u'Steven B. Bradlow'},
#      {u'name': u'Oscar Garcia-Prada'},
#      {u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14H30, 14H60, 32L05'}],
#     u'id': u'http://arxiv.org/abs/math/0206012v1',
#     u'link': [{u'@href': u'http://arxiv.org/abs/math/0206012v1',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0206012v1',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2002-06-03T13:23:50Z',
#     u'summary': u"Using the $L^2$ norm of the Higgs field as a Morse function, we study the\nmoduli spaces of $U(p,q)$-Higgs bundles over a Riemann surface. We require that\nthe genus of the surface be at least two, but place no constraints on $(p,q)$.\nA key step is the identification of the function's local minima as moduli\nspaces of holomorphic triples. We prove that these moduli spaces of triples are\nirreducible and non-empty.\n  Because of the relation between flat bundles and fundamental group\nrepresentations, we can interpret our conclusions as results about the number\nof connected components in the moduli space of semisimple\n$PU(p,q)$-representations. The topological invariants of the flat bundles\nbundle are used to label components. These invariants are bounded by a\nMilnor-Wood type inequality. For each allowed value of the invariants\nsatisfying a certain coprimality condition, we prove that the corresponding\ncomponent is non-empty and connected. If the coprimality condition does not\nhold, our results apply to the irreducible representations.",
#     u'title': u'Surface group representations, Higgs bundles, and holomorphic triples',
#     u'updated': u'2002-06-03T13:23:50Z'},
#    {u'arxiv:comment': {u'#text': u'44 pages. v2: minor clarifications and corrections, to appear in\n  Math. Annalen',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:doi': {u'#text': u'10.1007/s00208-003-0484-z',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:journal_ref': {u'#text': u'Math. Ann. 328 (2004), 299-351.',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Steven B. Bradlow'},
#      {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Oscar Garcia-Prada'},
#      {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14D20 (Primary) 14H60, 32G13 (Secondary)'}],
#     u'id': u'http://arxiv.org/abs/math/0211428v2',
#     u'link': [{u'@href': u'http://dx.doi.org/10.1007/s00208-003-0484-z',
#       u'@rel': u'related',
#       u'@title': u'doi'},
#      {u'@href': u'http://arxiv.org/abs/math/0211428v2',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0211428v2',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2002-11-27T15:06:44Z',
#     u'summary': u'A holomorphic triple over a compact Riemann surface consists of two\nholomorphic vector bundles and a holomorphic map between them. After fixing the\ntopological types of the bundles and a real parameter, there exist moduli\nspaces of stable holomorphic triples. In this paper we study non-emptiness,\nirreducibility, smoothness, and birational descriptions of these moduli spaces\nfor a certain range of the parameter. Our results have important applications\nto the study of the moduli space of representations of the fundamental group of\nthe surface into unitary Lie groups of indefinite signature, which we explore\nin a companion paper "Surface group representations in PU(p,q) and Higgs\nbundles". Another application, that we study in this paper, is to the existence\nof stable bundles on the product of the surface by the complex projective line.\n This paper, and its companion mentioned above, form a substantially revised\nversion of math.AG/0206012.',
#     u'title': u'Moduli spaces of holomorphic triples over compact Riemann surfaces',
#     u'updated': u'2003-10-02T09:13:55Z'},
#    {u'arxiv:comment': {u'#text': u'44 pages, 2 figures. Minor clarifications and corrections. Final\n  version, to appear in J. Diff. Geom',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:journal_ref': {u'#text': u'J. Diff. Geom. 64 (2003), 111-170.',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Steven B. Bradlow'},
#      {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Oscar Garcia-Prada'},
#      {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14D20 (Primary) 14H60, 32G13 (Secondary)'}],
#     u'id': u'http://arxiv.org/abs/math/0211431v3',
#     u'link': [{u'@href': u'http://arxiv.org/abs/math/0211431v3',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0211431v3',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2002-11-27T15:31:01Z',
#     u'summary': u'Using the L^2 norm of the Higgs field as a Morse function, we study the\nmoduli spaces of U(p,q)-Higgs bundles over a Riemann surface. We require that\nthe genus of the surface be at least two, but place no constraints on (p,q). A\nkey step is the identification of the function\'s local minima as moduli spaces\nof holomorphic triples. In a companion paper "Moduli spaces of holomorphic\ntriples over compact Riemann surfaces" (math.AG/0211428) we prove that these\nmoduli spaces of triples are non-empty and irreducible.\n Because of the relation between flat bundles and fundamental group\nrepresentations, we can interpret our conclusions as results about the number\nof connected components in the moduli space of semisimple\nPU(p,q)-representations. The topological invariants of the flat bundles are\nused to label subspaces. These invariants are bounded by a Milnor-Wood type\ninequality. For each allowed value of the invariants satisfying a certain\ncoprimality condition, we prove that the corresponding subspace is non-empty\nand connected. If the coprimality condition does not hold, our results apply to\nthe closure of the moduli space of irreducible representations.\n This paper, and its companion mentioned above, form a substantially revised\nversion of math.AG/0206012.',
#     u'title': u'Surface group representations in PU(p,q) and Higgs bundles',
#     u'updated': u'2003-07-11T08:54:37Z'},
#    {u'arxiv:comment': {u'#text': u'12 pages. v2: corrected statement of Theorem 5.2 (1), other minor\n  corrections. To appear in the Proceedings of the Fall Workshop on Geometry\n  and Physics, Coimbra 2003',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:journal_ref': {u'#text': u'Proceedings of the XII Fall Workshop on Geometry and Physics,\n  Coimbra 2003, Publicaciones de la RSME 7 (2004), 83-94',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Steven B. Bradlow'},
#      {u'arxiv:affiliation': {u'#text': u'IMAFF, CSIC, Madrid',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Oscar Garcia-Prada'},
#      {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14D20, 14F45, 14H60'}],
#     u'id': u'http://arxiv.org/abs/math/0401064v2',
#     u'link': [{u'@href': u'http://arxiv.org/abs/math/0401064v2',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0401064v2',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2004-01-07T17:29:15Z',
#     u'summary': u'We determine the number of connected components of the moduli space for\nrepresentations of a surface group in the general linear group.',
#     u'title': u'Representations of surface groups in the general linear group',
#     u'updated': u'2004-01-19T11:28:48Z'},
#    {u'arxiv:comment': {u'#text': u'21 pages; v2: improved results for moduli of representations in\n  GL(n,C), provided proof of Proposition 4.13 (4.12 of v1) correcting argument\n  given in earlier paper, other minor corrections; v3: corrected Remark 4.6,\n  other minor corrections; v4: corrected statements of Proposition 4.17 and\n  Theorems 4.19 and 4.22 (former Theorems 4.18 and 4.20); to appear in Topology',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:doi': {u'#text': u'10.1016/j.top.2007.06.001',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:journal_ref': {u'#text': u'Topology 47 (2008), 203-224',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Steven B. Bradlow'},
#      {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Oscar Garcia-Prada'},
#      {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14H60, 57R57, 58D29'}],
#     u'id': u'http://arxiv.org/abs/math/0506444v4',
#     u'link': [{u'@href': u'http://dx.doi.org/10.1016/j.top.2007.06.001',
#       u'@rel': u'related',
#       u'@title': u'doi'},
#      {u'@href': u'http://arxiv.org/abs/math/0506444v4',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0506444v4',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2005-06-22T10:49:12Z',
#     u'summary': u'We calculate certain homotopy groups of the moduli spaces for representations\nof a compact oriented surface in the Lie groups GL(n,C) and U(p,q). Our\napproach relies on the interpretation of these representations in terms of\nHiggs bundles and uses Bott--Morse theory on the corresponding moduli spaces.',
#     u'title': u'Homotopy groups of moduli spaces of representations',
#     u'updated': u'2007-06-14T09:57:44Z'},
#    {u'arxiv:comment': {u'#text': u'v2: added due credits to the work of Burger, Iozzi and Wienhard. v3:\n  corrected count of connected components for G=SU(p,q) (p \\neq q); added due\n  credits to the work of Xia and Markman-Xia; minor corrections and\n  clarifications. 31 pages',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:doi': {u'#text': u'10.1007/s10711-007-9127-y',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:journal_ref': {u'#text': u'Geometriae Dedicata 122 (2006), 185-213',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Steven B. Bradlow'},
#      {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Oscar Garcia-Prada'},
#      {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14H60 (Primary) 57R57, 58D29 (Secondary)'}],
#     u'id': u'http://arxiv.org/abs/math/0511415v3',
#     u'link': [{u'@href': u'http://dx.doi.org/10.1007/s10711-007-9127-y',
#       u'@rel': u'related',
#       u'@title': u'doi'},
#      {u'@href': u'http://arxiv.org/abs/math/0511415v3',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0511415v3',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2005-11-16T16:07:34Z',
#     u'summary': u'Higgs bundles and non-abelian Hodge theory provide holomorphic methods with\nwhich to study the moduli spaces of surface group representations in a\nreductive Lie group G. In this paper we survey the case in which G is the\nisometry group of a classical Hermitian symmetric space of non-compact type.\nUsing Morse theory on the moduli spaces of Higgs bundles, we compute the number\nof connected components of the moduli space of representations with maximal\nToledo invariant.',
#     u'title': u'Maximal surface group representations in isometry groups of classical\n  Hermitian symmetric spaces',
#     u'updated': u'2006-11-27T11:57:56Z'},
#    {u'arxiv:comment': {u'#text': u'49 pages; v2: various improvements and minor corrections; v3:\n  improved exposition',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:doi': {u'#text': u'10.1093/qmath/har010',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:journal_ref': {u'#text': u'Q. J. Math. 63 (2012), 795-843',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Steven B. Bradlow'},
#      {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Oscar Garcia-Prada'},
#      {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14H60 (Primary) 57M99, 22E99 (Secondary)'}],
#     u'id': u'http://arxiv.org/abs/0903.5496v3',
#     u'link': [{u'@href': u'http://dx.doi.org/10.1093/qmath/har010',
#       u'@rel': u'related',
#       u'@title': u'doi'},
#      {u'@href': u'http://arxiv.org/abs/0903.5496v3',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/0903.5496v3',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2009-03-31T15:13:08Z',
#     u'summary': u'We use Higgs bundles to answer the following question: When can a maximal\nSp(4,R)-representation of a surface group be deformed to a representation which\nfactors through a proper reductive subgroup of Sp(4,R)?',
#     u'title': u'Deformations of maximal representations in Sp(4,R)',
#     u'updated': u'2010-06-07T07:30:49Z'},
#    {u'arxiv:comment': {u'#text': u'43 pages; v2: minor corrections and improvements, appendix\n  significantly shortened (the removed material will appear elsewhere); v3:\n  final version with many minor corrections and improvements, to appear in\n  Geometriae Dedicata',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois at Urbana-Champaign',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Steven B. Bradlow'},
#      {u'arxiv:affiliation': {u'#text': u'ICMAT-CSIC, Madrid',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Oscar Garcia-Prada'},
#      {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14H60 (Primary) 53C07, 58D29 (Secondary)'}],
#     u'id': u'http://arxiv.org/abs/1303.1058v3',
#     u'link': [{u'@href': u'http://arxiv.org/abs/1303.1058v3',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/1303.1058v3',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2013-03-05T15:05:48Z',
#     u'summary': u'Higgs bundles over a closed orientable surface can be defined for any real\nreductive Lie group G. In this paper we examine the case G=SO*(2n). We describe\na rigidity phenomenon encountered in the case of maximal Toledo invariant.\nUsing this and Morse theory in the moduli space of Higgs bundles, we show that\nthe moduli space is connected in this maximal Toledo case. The Morse theory\nalso allows us to show connectedness when the Toledo invariant is zero. The\ncorrespondence between Higgs bundles and surface group representations thus\nallows us to count the connected components with zero and maximal Toledo\ninvariant in the moduli space of representations of the fundamental group of\nthe surface in SO*(2n).',
#     u'title': u'Higgs bundles for the non-compact dual of the special orthogonal group',
#     u'updated': u'2014-10-16T14:57:58Z'},
#    {u'arxiv:comment': {u'#text': u'6 pages, to appear in C. R. Acad. Sci. Paris Ser. I Math',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:doi': {u'#text': u'10.1016/S0764-4442(01)02069-9',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:journal_ref': {u'#text': u"C. R. Acad. Sci. Paris S\\'er. I Math. 333 (2001), 347-352",
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#      u'@term': u'math.AG',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Steven B. Bradlow'},
#      {u'arxiv:affiliation': {u'#text': u'Universidad Autonoma de Madrid',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Oscar Garcia-Prada'},
#      {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#        u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#       u'name': u'Peter B. Gothen'}],
#     u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'math.AG'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.RT'},
#      {u'@scheme': u'http://arxiv.org/schemas/atom',
#       u'@term': u'14D20 (Primary) 14F45, 14H60, 32G13 (Secondary)'}],
#     u'id': u'http://arxiv.org/abs/math/0107103v1',
#     u'link': [{u'@href': u'http://dx.doi.org/10.1016/S0764-4442(01)02069-9',
#       u'@rel': u'related',
#       u'@title': u'doi'},
#      {u'@href': u'http://arxiv.org/abs/math/0107103v1',
#       u'@rel': u'alternate',
#       u'@type': u'text/html'},
#      {u'@href': u'http://arxiv.org/pdf/math/0107103v1',
#       u'@rel': u'related',
#       u'@title': u'pdf',
#       u'@type': u'application/pdf'}],
#     u'published': u'2001-07-13T10:01:35Z',
#     u'summary': u"We count the connected components in the moduli space of\nPU(p,q)-representations of the fundamental group for a closed oriented surface.\nThe components are labelled by pairs of integers which arise as topological\ninvariants of the flat bundles associated to the representations. Our results\nshow that for each allowed value of these invariants, which are bounded by a\nMilnor-Wood type inequality, there is a unique non-empty connected component.\nInterpreting the moduli space of representations as a moduli space of Higgs\nbundles, we take a Morse theoretic approach using a certain smooth proper\nfunction on the Higgs moduli space. A key step is the identification of the\nfunction's local minima as moduli spaces of holomorphic triples. We prove that\nthese moduli spaces of triples are non-empty and irreducible.",
#     u'title': u'Representations of the fundamental group of a surface in PU(p,q) and\n  holomorphic triples',
#     u'updated': u'2001-07-13T10:01:35Z'}],
#   u'id': u'http://arxiv.org/api/BwrHdiSEp9G7WlezC8Q3e8VNMJk',
#   u'link': {u'@href': u'http://arxiv.org/api/query?search_query%3Dau%3ABradlow_Steven%20AND%20au%3AGothen_Peter%26id_list%3D%26start%3D0%26max_results%3D1000',
#    u'@rel': u'self',
#    u'@type': u'application/atom+xml'},
#   u'opensearch:itemsPerPage': {u'#text': u'1000',
#    u'@xmlns:opensearch': u'http://a9.com/-/spec/opensearch/1.1/'},
#   u'opensearch:startIndex': {u'#text': u'0',
#    u'@xmlns:opensearch': u'http://a9.com/-/spec/opensearch/1.1/'},
#   u'opensearch:totalResults': {u'#text': u'9',
#    u'@xmlns:opensearch': u'http://a9.com/-/spec/opensearch/1.1/'},
#   u'title': {u'#text': u'ArXiv Query: search_query=au:Bradlow_Steven AND au:Gothen_Peter&id_list=&start=0&max_results=1000',
#    u'@type': u'html'},
#   u'updated': u'2016-03-15T00:00:00-04:00'}}

# %%
hold['feed'][u'entry']
# Out:
# [{u'arxiv:comment': {u'#text': u'106 pages',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#    u'@term': u'math.AG',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'author': [{u'name': u'Steven B. Bradlow'},
#    {u'name': u'Oscar Garcia-Prada'},
#    {u'name': u'Peter B. Gothen'}],
#   u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'math.AG'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'14H30, 14H60, 32L05'}],
#   u'id': u'http://arxiv.org/abs/math/0206012v1',
#   u'link': [{u'@href': u'http://arxiv.org/abs/math/0206012v1',
#     u'@rel': u'alternate',
#     u'@type': u'text/html'},
#    {u'@href': u'http://arxiv.org/pdf/math/0206012v1',
#     u'@rel': u'related',
#     u'@title': u'pdf',
#     u'@type': u'application/pdf'}],
#   u'published': u'2002-06-03T13:23:50Z',
#   u'summary': u"Using the $L^2$ norm of the Higgs field as a Morse function, we study the\nmoduli spaces of $U(p,q)$-Higgs bundles over a Riemann surface. We require that\nthe genus of the surface be at least two, but place no constraints on $(p,q)$.\nA key step is the identification of the function's local minima as moduli\nspaces of holomorphic triples. We prove that these moduli spaces of triples are\nirreducible and non-empty.\n  Because of the relation between flat bundles and fundamental group\nrepresentations, we can interpret our conclusions as results about the number\nof connected components in the moduli space of semisimple\n$PU(p,q)$-representations. The topological invariants of the flat bundles\nbundle are used to label components. These invariants are bounded by a\nMilnor-Wood type inequality. For each allowed value of the invariants\nsatisfying a certain coprimality condition, we prove that the corresponding\ncomponent is non-empty and connected. If the coprimality condition does not\nhold, our results apply to the irreducible representations.",
#   u'title': u'Surface group representations, Higgs bundles, and holomorphic triples',
#   u'updated': u'2002-06-03T13:23:50Z'},
#  {u'arxiv:comment': {u'#text': u'44 pages. v2: minor clarifications and corrections, to appear in\n  Math. Annalen',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:doi': {u'#text': u'10.1007/s00208-003-0484-z',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:journal_ref': {u'#text': u'Math. Ann. 328 (2004), 299-351.',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#    u'@term': u'math.AG',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'math.AG'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'14D20 (Primary) 14H60, 32G13 (Secondary)'}],
#   u'id': u'http://arxiv.org/abs/math/0211428v2',
#   u'link': [{u'@href': u'http://dx.doi.org/10.1007/s00208-003-0484-z',
#     u'@rel': u'related',
#     u'@title': u'doi'},
#    {u'@href': u'http://arxiv.org/abs/math/0211428v2',
#     u'@rel': u'alternate',
#     u'@type': u'text/html'},
#    {u'@href': u'http://arxiv.org/pdf/math/0211428v2',
#     u'@rel': u'related',
#     u'@title': u'pdf',
#     u'@type': u'application/pdf'}],
#   u'published': u'2002-11-27T15:06:44Z',
#   u'summary': u'A holomorphic triple over a compact Riemann surface consists of two\nholomorphic vector bundles and a holomorphic map between them. After fixing the\ntopological types of the bundles and a real parameter, there exist moduli\nspaces of stable holomorphic triples. In this paper we study non-emptiness,\nirreducibility, smoothness, and birational descriptions of these moduli spaces\nfor a certain range of the parameter. Our results have important applications\nto the study of the moduli space of representations of the fundamental group of\nthe surface into unitary Lie groups of indefinite signature, which we explore\nin a companion paper "Surface group representations in PU(p,q) and Higgs\nbundles". Another application, that we study in this paper, is to the existence\nof stable bundles on the product of the surface by the complex projective line.\n This paper, and its companion mentioned above, form a substantially revised\nversion of math.AG/0206012.',
#   u'title': u'Moduli spaces of holomorphic triples over compact Riemann surfaces',
#   u'updated': u'2003-10-02T09:13:55Z'},
#  {u'arxiv:comment': {u'#text': u'44 pages, 2 figures. Minor clarifications and corrections. Final\n  version, to appear in J. Diff. Geom',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:journal_ref': {u'#text': u'J. Diff. Geom. 64 (2003), 111-170.',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#    u'@term': u'math.AG',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'math.AG'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'14D20 (Primary) 14H60, 32G13 (Secondary)'}],
#   u'id': u'http://arxiv.org/abs/math/0211431v3',
#   u'link': [{u'@href': u'http://arxiv.org/abs/math/0211431v3',
#     u'@rel': u'alternate',
#     u'@type': u'text/html'},
#    {u'@href': u'http://arxiv.org/pdf/math/0211431v3',
#     u'@rel': u'related',
#     u'@title': u'pdf',
#     u'@type': u'application/pdf'}],
#   u'published': u'2002-11-27T15:31:01Z',
#   u'summary': u'Using the L^2 norm of the Higgs field as a Morse function, we study the\nmoduli spaces of U(p,q)-Higgs bundles over a Riemann surface. We require that\nthe genus of the surface be at least two, but place no constraints on (p,q). A\nkey step is the identification of the function\'s local minima as moduli spaces\nof holomorphic triples. In a companion paper "Moduli spaces of holomorphic\ntriples over compact Riemann surfaces" (math.AG/0211428) we prove that these\nmoduli spaces of triples are non-empty and irreducible.\n Because of the relation between flat bundles and fundamental group\nrepresentations, we can interpret our conclusions as results about the number\nof connected components in the moduli space of semisimple\nPU(p,q)-representations. The topological invariants of the flat bundles are\nused to label subspaces. These invariants are bounded by a Milnor-Wood type\ninequality. For each allowed value of the invariants satisfying a certain\ncoprimality condition, we prove that the corresponding subspace is non-empty\nand connected. If the coprimality condition does not hold, our results apply to\nthe closure of the moduli space of irreducible representations.\n This paper, and its companion mentioned above, form a substantially revised\nversion of math.AG/0206012.',
#   u'title': u'Surface group representations in PU(p,q) and Higgs bundles',
#   u'updated': u'2003-07-11T08:54:37Z'},
#  {u'arxiv:comment': {u'#text': u'12 pages. v2: corrected statement of Theorem 5.2 (1), other minor\n  corrections. To appear in the Proceedings of the Fall Workshop on Geometry\n  and Physics, Coimbra 2003',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:journal_ref': {u'#text': u'Proceedings of the XII Fall Workshop on Geometry and Physics,\n  Coimbra 2003, Publicaciones de la RSME 7 (2004), 83-94',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#    u'@term': u'math.AG',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'IMAFF, CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'math.AG'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'14D20, 14F45, 14H60'}],
#   u'id': u'http://arxiv.org/abs/math/0401064v2',
#   u'link': [{u'@href': u'http://arxiv.org/abs/math/0401064v2',
#     u'@rel': u'alternate',
#     u'@type': u'text/html'},
#    {u'@href': u'http://arxiv.org/pdf/math/0401064v2',
#     u'@rel': u'related',
#     u'@title': u'pdf',
#     u'@type': u'application/pdf'}],
#   u'published': u'2004-01-07T17:29:15Z',
#   u'summary': u'We determine the number of connected components of the moduli space for\nrepresentations of a surface group in the general linear group.',
#   u'title': u'Representations of surface groups in the general linear group',
#   u'updated': u'2004-01-19T11:28:48Z'},
#  {u'arxiv:comment': {u'#text': u'21 pages; v2: improved results for moduli of representations in\n  GL(n,C), provided proof of Proposition 4.13 (4.12 of v1) correcting argument\n  given in earlier paper, other minor corrections; v3: corrected Remark 4.6,\n  other minor corrections; v4: corrected statements of Proposition 4.17 and\n  Theorems 4.19 and 4.22 (former Theorems 4.18 and 4.20); to appear in Topology',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:doi': {u'#text': u'10.1016/j.top.2007.06.001',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:journal_ref': {u'#text': u'Topology 47 (2008), 203-224',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#    u'@term': u'math.AG',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'math.AG'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'14H60, 57R57, 58D29'}],
#   u'id': u'http://arxiv.org/abs/math/0506444v4',
#   u'link': [{u'@href': u'http://dx.doi.org/10.1016/j.top.2007.06.001',
#     u'@rel': u'related',
#     u'@title': u'doi'},
#    {u'@href': u'http://arxiv.org/abs/math/0506444v4',
#     u'@rel': u'alternate',
#     u'@type': u'text/html'},
#    {u'@href': u'http://arxiv.org/pdf/math/0506444v4',
#     u'@rel': u'related',
#     u'@title': u'pdf',
#     u'@type': u'application/pdf'}],
#   u'published': u'2005-06-22T10:49:12Z',
#   u'summary': u'We calculate certain homotopy groups of the moduli spaces for representations\nof a compact oriented surface in the Lie groups GL(n,C) and U(p,q). Our\napproach relies on the interpretation of these representations in terms of\nHiggs bundles and uses Bott--Morse theory on the corresponding moduli spaces.',
#   u'title': u'Homotopy groups of moduli spaces of representations',
#   u'updated': u'2007-06-14T09:57:44Z'},
#  {u'arxiv:comment': {u'#text': u'v2: added due credits to the work of Burger, Iozzi and Wienhard. v3:\n  corrected count of connected components for G=SU(p,q) (p \\neq q); added due\n  credits to the work of Xia and Markman-Xia; minor corrections and\n  clarifications. 31 pages',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:doi': {u'#text': u'10.1007/s10711-007-9127-y',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:journal_ref': {u'#text': u'Geometriae Dedicata 122 (2006), 185-213',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#    u'@term': u'math.AG',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'math.AG'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'14H60 (Primary) 57R57, 58D29 (Secondary)'}],
#   u'id': u'http://arxiv.org/abs/math/0511415v3',
#   u'link': [{u'@href': u'http://dx.doi.org/10.1007/s10711-007-9127-y',
#     u'@rel': u'related',
#     u'@title': u'doi'},
#    {u'@href': u'http://arxiv.org/abs/math/0511415v3',
#     u'@rel': u'alternate',
#     u'@type': u'text/html'},
#    {u'@href': u'http://arxiv.org/pdf/math/0511415v3',
#     u'@rel': u'related',
#     u'@title': u'pdf',
#     u'@type': u'application/pdf'}],
#   u'published': u'2005-11-16T16:07:34Z',
#   u'summary': u'Higgs bundles and non-abelian Hodge theory provide holomorphic methods with\nwhich to study the moduli spaces of surface group representations in a\nreductive Lie group G. In this paper we survey the case in which G is the\nisometry group of a classical Hermitian symmetric space of non-compact type.\nUsing Morse theory on the moduli spaces of Higgs bundles, we compute the number\nof connected components of the moduli space of representations with maximal\nToledo invariant.',
#   u'title': u'Maximal surface group representations in isometry groups of classical\n  Hermitian symmetric spaces',
#   u'updated': u'2006-11-27T11:57:56Z'},
#  {u'arxiv:comment': {u'#text': u'49 pages; v2: various improvements and minor corrections; v3:\n  improved exposition',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:doi': {u'#text': u'10.1093/qmath/har010',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:journal_ref': {u'#text': u'Q. J. Math. 63 (2012), 795-843',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#    u'@term': u'math.AG',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'math.AG'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'14H60 (Primary) 57M99, 22E99 (Secondary)'}],
#   u'id': u'http://arxiv.org/abs/0903.5496v3',
#   u'link': [{u'@href': u'http://dx.doi.org/10.1093/qmath/har010',
#     u'@rel': u'related',
#     u'@title': u'doi'},
#    {u'@href': u'http://arxiv.org/abs/0903.5496v3',
#     u'@rel': u'alternate',
#     u'@type': u'text/html'},
#    {u'@href': u'http://arxiv.org/pdf/0903.5496v3',
#     u'@rel': u'related',
#     u'@title': u'pdf',
#     u'@type': u'application/pdf'}],
#   u'published': u'2009-03-31T15:13:08Z',
#   u'summary': u'We use Higgs bundles to answer the following question: When can a maximal\nSp(4,R)-representation of a surface group be deformed to a representation which\nfactors through a proper reductive subgroup of Sp(4,R)?',
#   u'title': u'Deformations of maximal representations in Sp(4,R)',
#   u'updated': u'2010-06-07T07:30:49Z'},
#  {u'arxiv:comment': {u'#text': u'43 pages; v2: minor corrections and improvements, appendix\n  significantly shortened (the removed material will appear elsewhere); v3:\n  final version with many minor corrections and improvements, to appear in\n  Geometriae Dedicata',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#    u'@term': u'math.AG',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois at Urbana-Champaign',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'ICMAT-CSIC, Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'math.AG'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.DG'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'14H60 (Primary) 53C07, 58D29 (Secondary)'}],
#   u'id': u'http://arxiv.org/abs/1303.1058v3',
#   u'link': [{u'@href': u'http://arxiv.org/abs/1303.1058v3',
#     u'@rel': u'alternate',
#     u'@type': u'text/html'},
#    {u'@href': u'http://arxiv.org/pdf/1303.1058v3',
#     u'@rel': u'related',
#     u'@title': u'pdf',
#     u'@type': u'application/pdf'}],
#   u'published': u'2013-03-05T15:05:48Z',
#   u'summary': u'Higgs bundles over a closed orientable surface can be defined for any real\nreductive Lie group G. In this paper we examine the case G=SO*(2n). We describe\na rigidity phenomenon encountered in the case of maximal Toledo invariant.\nUsing this and Morse theory in the moduli space of Higgs bundles, we show that\nthe moduli space is connected in this maximal Toledo case. The Morse theory\nalso allows us to show connectedness when the Toledo invariant is zero. The\ncorrespondence between Higgs bundles and surface group representations thus\nallows us to count the connected components with zero and maximal Toledo\ninvariant in the moduli space of representations of the fundamental group of\nthe surface in SO*(2n).',
#   u'title': u'Higgs bundles for the non-compact dual of the special orthogonal group',
#   u'updated': u'2014-10-16T14:57:58Z'},
#  {u'arxiv:comment': {u'#text': u'6 pages, to appear in C. R. Acad. Sci. Paris Ser. I Math',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:doi': {u'#text': u'10.1016/S0764-4442(01)02069-9',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:journal_ref': {u'#text': u"C. R. Acad. Sci. Paris S\\'er. I Math. 333 (2001), 347-352",
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'arxiv:primary_category': {u'@scheme': u'http://arxiv.org/schemas/atom',
#    u'@term': u'math.AG',
#    u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#   u'author': [{u'arxiv:affiliation': {u'#text': u'University of Illinois',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Steven B. Bradlow'},
#    {u'arxiv:affiliation': {u'#text': u'Universidad Autonoma de Madrid',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Oscar Garcia-Prada'},
#    {u'arxiv:affiliation': {u'#text': u'Universidade do Porto',
#      u'@xmlns:arxiv': u'http://arxiv.org/schemas/atom'},
#     u'name': u'Peter B. Gothen'}],
#   u'category': [{u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'math.AG'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom', u'@term': u'math.RT'},
#    {u'@scheme': u'http://arxiv.org/schemas/atom',
#     u'@term': u'14D20 (Primary) 14F45, 14H60, 32G13 (Secondary)'}],
#   u'id': u'http://arxiv.org/abs/math/0107103v1',
#   u'link': [{u'@href': u'http://dx.doi.org/10.1016/S0764-4442(01)02069-9',
#     u'@rel': u'related',
#     u'@title': u'doi'},
#    {u'@href': u'http://arxiv.org/abs/math/0107103v1',
#     u'@rel': u'alternate',
#     u'@type': u'text/html'},
#    {u'@href': u'http://arxiv.org/pdf/math/0107103v1',
#     u'@rel': u'related',
#     u'@title': u'pdf',
#     u'@type': u'application/pdf'}],
#   u'published': u'2001-07-13T10:01:35Z',
#   u'summary': u"We count the connected components in the moduli space of\nPU(p,q)-representations of the fundamental group for a closed oriented surface.\nThe components are labelled by pairs of integers which arise as topological\ninvariants of the flat bundles associated to the representations. Our results\nshow that for each allowed value of these invariants, which are bounded by a\nMilnor-Wood type inequality, there is a unique non-empty connected component.\nInterpreting the moduli space of representations as a moduli space of Higgs\nbundles, we take a Morse theoretic approach using a certain smooth proper\nfunction on the Higgs moduli space. A key step is the identification of the\nfunction's local minima as moduli spaces of holomorphic triples. We prove that\nthese moduli spaces of triples are non-empty and irreducible.",
#   u'title': u'Representations of the fundamental group of a surface in PU(p,q) and\n  holomorphic triples',
#   u'updated': u'2001-07-13T10:01:35Z'}]

# %%
print get_list(hold, "p1", "p2")
# Out:
# good
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-0107f63a2255> in <module>()
# ----> 1 print get_list(hold, "p1", "p2")
#
# <ipython-input-43-9216ef5609b7> in get_list(src, p1, p2)
#       9
#      10         score = 0
# ---> 11         for author in unit['authors'].values():
#      12             if if_same_person(p1, author['name']) or if_same_person(p2, author['name']):
#      13                 score += 1
#
# AttributeError: 'list' object has no attribute 'values'

# %%
for entry in hold['feed'][u'entry']:
    print "good"
# Out:
# good
# good
# good
# good
# good
# good
# good
# good
# good
